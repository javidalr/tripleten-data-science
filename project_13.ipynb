# %% [markdown]
# # ¡Hola Javier! 😊
#
# Mi nombre es **Alejandro Castellanos** y hoy tengo el placer de ser el revisor de tu proyecto.
#
# Voy a revisar todo tu código con detalle, buscando tanto los puntos fuertes como aquellos en los que podrías mejorar. Te dejaré comentarios a lo largo del notebook, destacando lo que has hecho bien y sugiriendo ajustes donde sea necesario. Si encuentro algún error, no te preocupes, te lo haré saber de forma clara y te daré información útil para que puedas corregirlo en la próxima iteración. Si en algún punto tienes comentarios, siéntete libre de dejarlos también.
#
#
# Encontrarás mis comentarios específicos dentro de cajas verdes, amarillas o rojas, es muy importante que no muevas, modifiques o borres mis comentarios, con el fin de tener un seguimiento adecuado de tu proceso:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si todo está perfecto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma:
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class=“tocSkip”></a>
# </div>
#
# A continuación te dejaré un comentario general con mi valoración del proyecto. **¡Mi objetivo es que sigas aprendiendo y mejorando con cada paso!**

# %% [markdown]
# ----

# %% [markdown]
# <h1><center>Sweet Lift Taxi - Prediccion de Numero de pedidos de Taxi para la siguiente hora</center></h1>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Descripción-del-proyecto" data-toc-modified-id="Descripción-del-proyecto-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Descripción del proyecto</a></span><ul class="toc-item"><li><span><a href="#Problema-de-Negocio" data-toc-modified-id="Problema-de-Negocio-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Problema de Negocio</a></span></li><li><span><a href="#Instrucciones-del-proyecto." data-toc-modified-id="Instrucciones-del-proyecto.-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Instrucciones del proyecto.</a></span></li><li><span><a href="#Objetivos" data-toc-modified-id="Objetivos-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Objetivos</a></span></li><li><span><a href="#Propuesta-del-proyecto" data-toc-modified-id="Propuesta-del-proyecto-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Propuesta del proyecto</a></span></li></ul></li><li><span><a href="#Preparación" data-toc-modified-id="Preparación-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Preparación</a></span><ul class="toc-item"><li><span><a href="#Descripción-de-los-datos" data-toc-modified-id="Descripción-de-los-datos-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Descripción de los datos</a></span></li><li><span><a href="#Ambiente-y-Librerias" data-toc-modified-id="Ambiente-y-Librerias-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Ambiente y Librerias</a></span></li><li><span><a href="#Funciones" data-toc-modified-id="Funciones-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Funciones</a></span></li><li><span><a href="#Carga-y-lectura-de-datos" data-toc-modified-id="Carga-y-lectura-de-datos-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Carga y lectura de datos</a></span></li><li><span><a href="#Pre-procesamiento-de-datos" data-toc-modified-id="Pre-procesamiento-de-datos-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Pre-procesamiento de datos</a></span><ul class="toc-item"><li><span><a href="#Cambio-tipo-de-datos" data-toc-modified-id="Cambio-tipo-de-datos-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Cambio tipo de datos</a></span></li><li><span><a href="#Establecer-variable-datetime-como-indice" data-toc-modified-id="Establecer-variable-datetime-como-indice-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Establecer variable datetime como indice</a></span></li><li><span><a href="#Verificar-orden-cronologico-creciente-y-monotono-de-los-datos" data-toc-modified-id="Verificar-orden-cronologico-creciente-y-monotono-de-los-datos-2.5.3"><span class="toc-item-num">2.5.3&nbsp;&nbsp;</span>Verificar orden cronologico creciente y monotono de los datos</a></span></li><li><span><a href="#Remuestreo-de-los-intervalos-de-tiempo" data-toc-modified-id="Remuestreo-de-los-intervalos-de-tiempo-2.5.4"><span class="toc-item-num">2.5.4&nbsp;&nbsp;</span>Remuestreo de los intervalos de tiempo</a></span></li></ul></li></ul></li><li><span><a href="#Análisis" data-toc-modified-id="Análisis-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Análisis</a></span><ul class="toc-item"><li><span><a href="#Tendencia-y-Estacionalidad" data-toc-modified-id="Tendencia-y-Estacionalidad-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Tendencia y Estacionalidad</a></span><ul class="toc-item"><li><span><a href="#Conjunto-de-datos-original" data-toc-modified-id="Conjunto-de-datos-original-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Conjunto de datos original</a></span></li><li><span><a href="#Remuestreo-de-1-hora" data-toc-modified-id="Remuestreo-de-1-hora-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Remuestreo de 1 hora</a></span></li><li><span><a href="#Remuestreo-de-1-dia" data-toc-modified-id="Remuestreo-de-1-dia-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Remuestreo de 1 dia</a></span></li><li><span><a href="#Media-movil" data-toc-modified-id="Media-movil-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Media movil</a></span></li><li><span><a href="#Mes-de-Agosto" data-toc-modified-id="Mes-de-Agosto-3.1.5"><span class="toc-item-num">3.1.5&nbsp;&nbsp;</span>Mes de Agosto</a></span></li><li><span><a href="#Semana-del-13-al-19-Agosto" data-toc-modified-id="Semana-del-13-al-19-Agosto-3.1.6"><span class="toc-item-num">3.1.6&nbsp;&nbsp;</span>Semana del 13 al 19 Agosto</a></span></li><li><span><a href="#Dia-7-de-Agosto" data-toc-modified-id="Dia-7-de-Agosto-3.1.7"><span class="toc-item-num">3.1.7&nbsp;&nbsp;</span>Dia 7 de Agosto</a></span></li></ul></li><li><span><a href="#Estacionariedad" data-toc-modified-id="Estacionariedad-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Estacionariedad</a></span><ul class="toc-item"><li><span><a href="#Desviacion-Estandar" data-toc-modified-id="Desviacion-Estandar-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Desviacion Estandar</a></span></li><li><span><a href="#Prueba-Aumentada-de-Dickey-Fuller" data-toc-modified-id="Prueba-Aumentada-de-Dickey-Fuller-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Prueba Aumentada de Dickey-Fuller</a></span></li><li><span><a href="#Prueba-de-Kwiatkowski-Phillips-Schmidt-Shin" data-toc-modified-id="Prueba-de-Kwiatkowski-Phillips-Schmidt-Shin-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Prueba de Kwiatkowski-Phillips-Schmidt-Shin</a></span></li></ul></li></ul></li><li><span><a href="#Entrenamiento-y-Prueba" data-toc-modified-id="Entrenamiento-y-Prueba-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Entrenamiento y Prueba</a></span><ul class="toc-item"><li><span><a href="#Modelo-ARIMA" data-toc-modified-id="Modelo-ARIMA-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Modelo ARIMA</a></span><ul class="toc-item"><li><span><a href="#Particion-de-los-datos" data-toc-modified-id="Particion-de-los-datos-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Particion de los datos</a></span></li><li><span><a href="#Buscar-mejores-parametros-con-Auto-ARIMA-(p-d-q)" data-toc-modified-id="Buscar-mejores-parametros-con-Auto-ARIMA-(p-d-q)-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Buscar mejores parametros con Auto ARIMA (p-d-q)</a></span></li><li><span><a href="#Prueba-de-Modelo-ARIMA" data-toc-modified-id="Prueba-de-Modelo-ARIMA-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Prueba de Modelo ARIMA</a></span></li></ul></li><li><span><a href="#Modelos-de-Machine-Learning" data-toc-modified-id="Modelos-de-Machine-Learning-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Modelos de Machine Learning</a></span><ul class="toc-item"><li><span><a href="#Dataset-con-nuevas-caracteristicas" data-toc-modified-id="Dataset-con-nuevas-caracteristicas-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Dataset con nuevas caracteristicas</a></span></li><li><span><a href="#Particion-del-nuevo-dataset" data-toc-modified-id="Particion-del-nuevo-dataset-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Particion del nuevo dataset</a></span></li></ul></li><li><span><a href="#Linear-Regression" data-toc-modified-id="Linear-Regression-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Linear Regression</a></span></li><li><span><a href="#Decision-Tree-Regressor" data-toc-modified-id="Decision-Tree-Regressor-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Decision Tree Regressor</a></span></li><li><span><a href="#Random-Forest-Regressor" data-toc-modified-id="Random-Forest-Regressor-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Random Forest Regressor</a></span></li><li><span><a href="#XGBoost-Regressor" data-toc-modified-id="XGBoost-Regressor-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>XGBoost Regressor</a></span></li><li><span><a href="#LightGBM-Regressor" data-toc-modified-id="LightGBM-Regressor-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>LightGBM Regressor</a></span></li><li><span><a href="#Catboost-Regressor" data-toc-modified-id="Catboost-Regressor-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Catboost Regressor</a></span></li></ul></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# ¡Gran Idea! El uso de una tabla de contenido es una excelente estrategia para mejorar la estructura del notebook y facilitar su revisión.
#
# </div>

# %% [markdown]
# ## Descripción del proyecto
#
# ### Problema de Negocio
#
# La compañía Sweet Lift Taxi ha recopilado datos históricos sobre pedidos de taxis en los aeropuertos. Para atraer a más conductores durante las horas pico, necesitamos predecir la cantidad de pedidos de taxis para la próxima hora. Construye un modelo para dicha predicción.
#
# La métrica RECM en el conjunto de prueba no debe ser superior a 48.
#
# ### Instrucciones del proyecto.
#
# 1. Descarga los datos y haz el remuestreo por una hora.
#
# 2. Analiza los datos
#
# 3. Entrena diferentes modelos con diferentes hiperparámetros. La muestra de prueba debe ser el 10% del conjunto de datos inicial.
#
# 4. Prueba los datos usando la muestra de prueba y proporciona una conclusión.
#
# ### Objetivos
#
# - Entrenar y comparar el desempeño de diferentes modelos, aplicados a series temporales.
#
#
# - Resultados con un RMSE inferior a 48.
#
#
# - Seleccionar el modelo mas optimo, que cumpla con los requisitos del cliente.
#
#
#
# ### Propuesta del proyecto
#
# El proyecto se compondrá de las siguientes etapas
#
# **1. Carga y Lectura de datos**
#   - Carga del dataset desde el archivo `taxi.csv`
#   - Explorar conjunto de datos para comprender sus variables y estructura.
#   - Verificar la existencia de valores ausentes, duplicados, los tipos de datos y estadisticas basicas.
#
# **2. Preparacion de los datos**
#   - Tratamiento de los datos ausentes, duplicados, erroneos, etc.
#   - Verificacion de orden cronologico creciente y monotono de la serie.
#   - Tecnica de remuestreo para ver y analizar la serie en distintas temporalidades.
#   - Analisis las tendencias y estacionalidad de las temporalidades de la serie.
#   - Pruebas estadisticas de estacionariedad..
#   - Particion de los datos en conjuntos de entrenamiento y prueba.
#
# **3. Entrenamiento de los modelos**
#   - Crear nuevo dataset, con caracteristicas adicionaales para modelos de Machine Learning.
#   - Entrenar y probar diferentes modelos, tradicionales como `ARIMA`, y de Machine Learning como `Linear Regression`, `Decision Tree Regressor`, `Random Forest Regressor`, `XGBoost Regressor`, `LightGBM Regressor` y `CatBoost Regressor`.
#   - Pruebas sin y con ajuste hiperparametros, analisis de los resultados de `RMSE`.
#
# **4. Analisis del modelo**
#   - Resumen general del desempeño de los modelos.
#   - Analizar y seleccionar el modelo mas optimo para las condiciones que solicita el cliente

# %% [markdown]
# ## Preparación
#
# ### Descripción de los datos
#
# Los datos se almacenan en el archivo `taxi.csv`.
# El número de pedidos está en la columna `num_orders`.

# %% [markdown]
# ### Ambiente y Librerias

# %%
# Ambiente de python

# !python --version
# Out:
# Python 3.10.8

# %%
# Importando librerias

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error, make_scorer
from statsmodels.tsa.seasonal import seasonal_decompose
import statsmodels.api as sm
from statsmodels.tsa.stattools import kpss
from statsmodels.tsa.arima.model import ARIMA

from scipy.stats import randint as sp_randInt
from scipy.stats import uniform as sp_randFloat

from pmdarima import auto_arima

from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor

import warnings
warnings.filterwarnings('ignore')

# Semilla de aleatoriedad
seed = 200

# %% [markdown]
# ### Funciones

# %%
# 1.Contexto general del conjunto de datos

def info_data(data):
    
    print('1. Tabla de datos primeras filas  ')
    display(data.head())
    print('='*100)
    print()

    print('2. Tabla de datos ultimas filas')
    display(data.tail())
    print('='*100)
    print()    
    
    print('3. Registros y variables')
    print()
    print('Registros: ', data.shape[0])
    print()
    print('Variables: ', data.shape[1])
    print('='*100)
    print()

    print('4. Resumen general del dataset')
    print(data.info())
    print('='*100)
    print()

    print('5. Resumen estadistico del dataset')
    print()
    print(data.describe())
    print('='*100)
    print()

    print('6. Valores duplicados por variable')
    print()
    print(data.duplicated().sum())
    print('='*100)
    print()

    print('7. Valores ausentes por variable')
    print()
    print(data.isna().sum())
    print('='*100)
    print()
    
    
# 2.Graficos de remuestreo

def resample_graphics(df):
    
    decomposed = seasonal_decompose(df)
    plt.figure(figsize = (15, 12))
    plt.subplot(411)
    plt.plot(df)
    plt.title('Datos Reales')

    plt.subplot(412)
    decomposed.trend.plot(ax = plt.gca())
    plt.title('Tendencia')

    plt.subplot(413)
    decomposed.seasonal.plot(ax = plt.gca())
    plt.title('Estacionalidad')

    plt.subplot(414)
    decomposed.resid.plot(ax = plt.gca())
    plt.title('Residuales')

    plt.tight_layout()



# 3. Prueba Aumentada de Dickey-Fuller

def adf_test(series):
    
    result = sm.tsa.stattools.adfuller(series)
    print('Prueba Estatdistica ADF: {:.3f}'.format(result[0]))
    print('p-value: {:.3f}'.format(result[1]))
    print('Valores criticos:')
    
    for key, value in result[4].items():
        print('\t{}: {:.3f}'.format(key, value))
    
    if result[0] < result[4]['5%']:
        print()
        print('Se rechaza hipotesis nula, los datos son estacionarios')
    
    else:
        print()
        print('No se rechaza hipotesis nula, los datos no son estacionarios')

        
# 4. Prueba Kwiatkowski-Phillips-Schmidt-Shin

def kpss_test(timeseries):
    
    result = kpss(timeseries)
    print('Prueba Estadistica KPSS:', result[0])
    print('p-value:', result[1])
    print('Rezagos usados:', result[2])
    print('Valores criticos:')
    
    for key, value in result[3].items():
        print(f'   {key}: {value}')
        
    alpha = 0.05
    
    if result[1] < alpha:
        print()
        print("P-value es menor que alpha. Se rechaza hipotesis nula.")
        print("La serie temporal es estacionaria.")
    
    else:
        print()
        print("P-value es mayor que alpha. No se rechaza la hipotesis nula.")
        print("La serie temporal no es estacionaria.")


# 5.Calcula el RMSE 

def rmse(y_actual, y_pred):
    
    return mean_squared_error(y_actual, y_pred, squared = False) 


# 6.Entrenamiento de modelo sin ajuste de hiperparametros

def train_model_no_tuning(model, features, target):
    scores = cross_val_score(model, features, target, scoring = rmse_scorer, cv = 5).mean()
    
    return scores


# 7.Entrenamiento de modelo con ajuste de hiperparametros

def train_model_tuning(model, features, target, param_distributions):
    
    # Creacion de calificador, con parametro 'greater_is_better'
    scorer = make_scorer(rmse, greater_is_better = False)

    # Definir un objeto RandomizedSearchCV
    random_search = RandomizedSearchCV(model, param_distributions = param_distributions,
                                       scoring = scorer, n_iter = 10, cv = 5, n_jobs = -1, random_state = seed)

    random_search.fit(features, target)
    
    # # Mostrar los mejores parametros y el RMSE
    print("Best Estimator:", random_search.best_estimator_)
    print("Best Parameters:", random_search.best_params_)
    print("Best RMSE:", -1 * random_search.best_score_)
    

# 8. Graficos comparacion valores actuales vs valores predecidos

def graph_real_predict(predict_model, color_real, color_predict):
    
    # Coincidir en el indice
    predict = pd.DataFrame(predict_model).set_index(target_test.index)
    
    plt.figure(figsize = (20, 5))
    plt.plot(target_test, color = color_real, label = 'Actuales')
    plt.plot(predict, color = color_predict, label = 'Predecidos')
    plt.legend()
    plt.title('Valores Actuales vs Valores Predecidos')
    plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Gran estrategía desarrollar tu proyecto mediante funciones. Has estructurado muy bien tu estrategia de análisis, abarcando desde la exploración inicial de los datos hasta la evaluación y comparación de modelos predictivos. Tus funciones están bien organizadas y facilitan la reutilización del código, lo que mejora la eficiencia y claridad del análisis. Destaca especialmente el uso de pruebas estadísticas como ADF y KPSS para evaluar la estacionariedad de la serie temporal, así como la implementación de validación cruzada y ajuste de hiperparámetros para optimizar el rendimiento del modelo. Además, la inclusión de gráficos de descomposición y comparación de predicciones con valores reales aporta una visualización clara del comportamiento de los datos y la calidad del modelo. ¡Muy buen trabajo!
#
# </div>

# %% [markdown]
# ### Carga y lectura de datos

# %%
# Carga y muestra de datos

try:
    data = pd.read_csv('/datasets/taxi.csv')
except:
    data = pd.read_csv('taxi.csv')

# %%
# Revisando el conjunto de datos

info_data(data)
# Out:
# 1. Tabla de datos primeras filas
#               datetime  num_orders
# 0  2018-03-01 00:00:00           9
# 1  2018-03-01 00:10:00          14
# 2  2018-03-01 00:20:00          28
# 3  2018-03-01 00:30:00          20
# 4  2018-03-01 00:40:00          32
# ...
#
# 2. Tabla de datos ultimas filas
#                   datetime  num_orders
# 26491  2018-08-31 23:10:00          32
# 26492  2018-08-31 23:20:00          24
# 26493  2018-08-31 23:30:00          27
# 26494  2018-08-31 23:40:00          39
# 26495  2018-08-31 23:50:00          53
# ...
#
# 3. Registros y variables
#
# Registros:  26496
#
# Variables:  2
# ...
#
# 4. Resumen general del dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26496 entries, 0 to 26495
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    26496 non-null  object
#  1   num_orders  26496 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 414.1+ KB
# None
# ...
#
# ...

# %% [markdown]
# **Hallazgos**
#
#
# - El conjunto de datos contiene 2 variables (columnas) y 26496 observaciones (filas).
#
#
# - Es necesario modificar el tipo de datos de la columna `datetime`, de object(string) a fecha(datetime64).
#
#
# - Establecer la columna `datetime` que contiene fechas, como indice del conjunto de datos, dejando solo la variable `num_orders`.
#
#
# - Revisar si los datos estan en orden creciente y de manera monotona, segun la variable `datetime`.
#
#
# - El dataset no tiene valores ausentes ni valores duplicados.
#
#
# - El tamaño del conjunto de datos es pequeño, tiene solo 414 KB.
#
#
# - Los registros van desde el `01 marzo hasta el 31 agosto del año 2018`, lo que son `6 meses` de registros.
#
#
# - Los pedidos se registran en intervalos de 10 minutos, por lo que se hara un remuestreo de la informacion, para obtener intervalos de 1 hora.
#
#
# - Los valores de media y mediana de la columna `num_orders` son proximos, 14.07 y 13 respectivamente, lo que sugiere una distribucion relativamente uniforme.
#
#
# - El numero de pedidos varia entre 0 y 119 en cada intervalo de tiempo, esto significa que aleatoriamente en 10 minutos no existe demanda, o se generan hasta 119 solicitudes de taxis, en el mismo lapso de tiempo.
#
#
# - Agregar columnas con informacion del año, mes, dia, dia de la semana y la diferencia

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Javier tu análisis demuestra un manejo sólido y meticuloso del conjunto de datos, destacando tu capacidad para identificar aspectos clave como la necesidad de ajustar el tipo de datos en la columna datetime y establecerla como índice. Has detectado correctamente la ausencia de valores duplicados o faltantes, lo que refleja un buen entendimiento de la integridad de los datos. Además, tu observación sobre la proximidad entre la media y la mediana sugiere una distribución equilibrada, lo cual es un hallazgo relevante para interpretar el comportamiento de la demanda. La propuesta de remuestrear los datos para intervalos de una hora y enriquecer el conjunto con nuevas columnas temporales evidencia una visión clara de cómo optimizar la información para análisis posteriores.
#
# </div>

# %% [markdown]
# ### Pre-procesamiento de datos
#
# Se abordan las problematicas del conjunto de datos, y otras condiciones.

# %% [markdown]
# #### Cambio tipo de datos

# %%
# Conversion de string a fecha, y resultado

data['datetime'] = data['datetime'].astype('datetime64')
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26496 entries, 0 to 26495
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    26496 non-null  datetime64[ns]
#  1   num_orders  26496 non-null  int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 414.1 KB
# None

# %% [markdown]
# #### Establecer variable datetime como indice

# %%
data.set_index('datetime', inplace = True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB

# %% [markdown]
# #### Verificar orden cronologico creciente y monotono de los datos

# %%
data.sort_index(inplace = True)
print(data.index.is_monotonic_increasing)
# Out:
# True

# %% [markdown]
# #### Remuestreo de los intervalos de tiempo

# %%
# Remuestreo de los intervalos de la serie de 10 minutos a 1 hora

data_1h = data.resample('1H').sum()
data_1h.head(10)
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00         124
# 2018-03-01 01:00:00          85
# 2018-03-01 02:00:00          71
# 2018-03-01 03:00:00          66
# 2018-03-01 04:00:00          43
# 2018-03-01 05:00:00           6
# 2018-03-01 06:00:00          12
# 2018-03-01 07:00:00          15
# 2018-03-01 08:00:00          34
# 2018-03-01 09:00:00          69

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Excelente trabajo ajustando los datos, esto permitirá llevar a cabo un correcto análisis
#
# </div>

# %% [markdown]
# ## Análisis
#
# En este capitulo, se profundizara el analisis de las caracteristicas del conjunto de datos.

# %% [markdown]
# ### Tendencia y Estacionalidad

# %% [markdown]
# #### Conjunto de datos original

# %%
# Grafica de los datos originales (Sin remuestreo)

data.plot(figsize=(20, 5))
plt.show()

# %% [markdown]
# Los datos tienen una forma relativamente densa, con los intervalos de tiempo cada 10 mninutos. Por ello, y por los requisitos de prediccion del cliente, anteriormente se realizo un remuestreo de los datos, modificando el intervalo de tiempo a 1 hora, ya que el proposito de este proyecto es predecir la demanda de taxis para la siguiente hora.
#
# Con los datos ya modificados, se analizaran las tendencias y la estacionalidad de la serie temporal.

# %% [markdown]
# #### Remuestreo de 1 hora

# %%
# Grafica de datos

resample_graphics(data_1h)

# %% [markdown]
# El conjunto de datos muestra una clara tendencia creciente, a lo largo de los meses, especialmente un agosto que se observa un aumento sostenido en los pedidos.
#
# Por otra parte, los patrones de estacionalidad son complejos de distinguir, con los intervalos de 1 hora.
#
# Para entender mejor la estacionalidad, se hara nuevamente un remuestreo, pasando de 1 hora, a 1 dia.

# %% [markdown]
# #### Remuestreo de 1 dia

# %%
data_day = data.resample('1D').sum()
resample_graphics(data_day)

# %% [markdown]
# La tendencia creciente es mas evidente, y los patrones de estacionalidad empiezan a mostrarse. Se calculara la media movil a partir de estos datos diarios.

# %% [markdown]
# #### Media movil

# %%
data_day['rolling_mean'] = data_day.rolling(10).mean()
data_day.plot(figsize=(20,5))
plt.show()

# %% [markdown]
# La media movil calculada a partir de los datos diarios corrobora la tendencia creciente en el numero de pedidos de taxis (`num_orders`), lo cual coincide con la tendencia observada en los graficos anteriores, por ultimo, apunta a que la cantidad de pedidos de taxis tiende aumentar en agosto.
#
# Desarrollo de una investigacion mas profunda, de los datos horarios-diarios en agosto, para analizar mas a fondo las tendencias y patrones de estacionalidad.

# %% [markdown]
# #### Mes de Agosto

# %%
data_month_august = data_1h['2018-08-01':'2018-08-30']
resample_graphics(data_month_august)

# %% [markdown]
# Se observa una tendencia inestable en el numero de pedidos(`num_orders`), con un aumento progresivo hacia el termino del mes. El patron de estacionalidad es sutil, pero se repite diariamente.
#
# Por lo anterior, se examinan los datos a nivel semanal, con enfoque en la muestra correspondiente a la semana del `lunes 13 al domingo 19 de Agosto del 2018`.

# %% [markdown]
# #### Semana del 13 al 19 Agosto

# %%
data_week_august = data_1h['2018-08-13':'2018-08-19']
resample_graphics(data_week_august)

# %% [markdown]
# La tendencia consigue el maximo de solicitudes el dia sabado 18 de Agosto de 2018, lo cual se contrasta con el dia siguente, ya que el dia 19 de Agosto del mismo periodo, esta alcanza su valor mas bajo.
#
# El cliente ha solicitado la prediccion de pedidos por hora, se analizara la tendencia de datos horarios para un solo dia, con enfoque en el dia 7 de Agosto de 2018 y estudiar el patron diario.

# %% [markdown]
# #### Dia 7 de Agosto

# %%
# Rescate de datos de una semana
data_one_week = data_1h.loc['2018-08-13':'2018-08-19']

# Datos por fecha en un solo grafico
fig, ax = plt.subplots(figsize = (15, 5))
labels = []
for day, day_data in data_one_week.groupby(data_one_week.index.date):

    # Datos por hora y calculo de promedio
    hour_data = day_data.groupby(day_data.index.hour).mean()

    # Color de linea diferente para cada dia
    label = day.strftime('%Y-%m-%d')
    hour_data.plot(ax = ax,label = label)
    labels.append(label)

# Valores y etiquetas eje x
ax.set_xticks(hour_data.index)
ax.set_xticklabels([f'{hour}:00' for hour in hour_data.index])

ax.set_xlabel('Hora')
ax.set_ylabel('Datos')
ax.legend(labels = labels, loc = 'upper right')
plt.show()

# %% [markdown]
# Revisando el grafico diario, la demanda sigue una sigue una tendencia horaria similar toda la semana, donde el maximo se da a la hora de las 2 a.m., seguido por otros horarios como 10 a.m., 17 p.m. y 21 p.m..

# %% [markdown]
# ### Estacionariedad

# %% [markdown]
# Se realiza analisis de estacionariedad, para definir si los datos son estacionarios o no. Para iniciar, se revisa la desviacion estandar del conjunto de datos.

# %% [markdown]
# #### Desviacion Estandar

# %%
# Verificacion de la desviacion estandar

data_day['rolling_std'] = data_day['num_orders'].rolling(10).std()
data_day.plot(figsize = (20,5))
plt.show()

# %% [markdown]
# La desviacion estandar de los datos son presuntamente constantes, lo que implica posibles datos estacionarios en términos de varianza, a pesar de una tendencia creciente de la media movil.
#
# Para comprobar esto, se examinan las siguientes pruebas estadísticas como la `Prueba Aumentada de Dickey-Fuller (ADF)` y la `Prueba de Kwiatkowski-Phillips-Schmidt-Shin (KPSS)` en el conjunto de datos original.
#
# La hipótesis nula (H0), en ambas pruebas, establece que la serie temporal tiene una raíz unitaria, lo que significa que los datos no son estacionarios. La hipótesis alternativa (H1), es que la serie temporal no tiene una raíz unitaria y, por lo tanto, es estacionaria.
#
# La presencia de una raíz unitaria en datos de series temporales sugiere un comportamiento de camino aleatorio o no estacionariedad. Los datos no estacionarios suelen exhibir tendencias significativas o grandes fluctuaciones a lo largo del tiempo, lo que dificulta su predicción confiable mediante modelos tradicionales de series temporales.

# %% [markdown]
# #### Prueba Aumentada de Dickey-Fuller

# %%
# Aplicacion de funcion `adf_test`

adf_test(data_1h)
# Out:
# Prueba Estatdistica ADF: -3.069
# p-value: 0.029
# Valores criticos:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
#
# Se rechaza hipotesis nula, los datos son estacionarios

# %% [markdown]
# #### Prueba de Kwiatkowski-Phillips-Schmidt-Shin

# %%
# Aplicacion de funcion `kpss_test`
       
kpss_test(data_1h)
# Out:
# Prueba Estadistica KPSS: 10.913353384602186
# p-value: 0.01
# Rezagos usados: 32
# Valores criticos:
#    10%: 0.347
#    5%: 0.463
#    2.5%: 0.574
#    1%: 0.739
#
# P-value es menor que alpha. Se rechaza hipotesis nula.
# La serie temporal es estacionaria.

# %% [markdown]
# Según los resultados de nuestras prueba, estos datos son estadisticamente estacionarios. Como resultado, se pueden aplicar métodos analíticos tradicionales como ARIMA (Auto-Regressive Integrated Moving Average) a estos datos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Tu análisis de tendencias y estacionalidad está bien estructurado y detallado, utilizando remuestreo progresivo para identificar patrones a diferentes escalas temporales. La exploración de la serie temporal a nivel horario, diario y semanal proporciona una visión clara de la evolución de la demanda de taxis, resaltando patrones clave como picos de demanda en horarios específicos. Además, el uso de la media móvil refuerza la interpretación de la tendencia creciente. En cuanto a la evaluación de estacionariedad, la aplicación de las pruebas ADF y KPSS es un excelente enfoque para fundamentar el uso de modelos como ARIMA. ¡Buen trabajo en la justificación de cada paso y en la claridad de los resultados obtenidos!
#
# </div>

# %% [markdown]
# ## Entrenamiento y Prueba
#
# Los datos son estacionarios, lo que permite analizar mediante métodos tradicionales, como ARIMA, sin necesidad de ingeniería de características. Sin embargo, para obtener resultados óptimos, se examinan con el análisis tradicional y con los modelos de aprendizaje automático.

# %%
# Creacion de calificador para modelos

rmse_scorer = make_scorer(rmse)

# %% [markdown]
# ### Modelo ARIMA

# %% [markdown]
# #### Particion de los datos

# %%
# Conjuntos de entrenamiento y prueba, eliminacion de datos nulos

train, test = train_test_split(data_1h, shuffle = False, test_size = 0.1)
train = train.dropna()

print(train.shape)
print(test.shape)
# Out:
# (3974, 1)
# (442, 1)

# %%
# Visualizacion de la particion de los datos

plt.figure(figsize = (20,5))
sns.lineplot(x = train.index, y = train['num_orders']);
sns.lineplot(x = test.index, y = test['num_orders']);

# %% [markdown]
# Los datos se han fraccionado correctamente segun lo solicitado, con la asignacion de un 10% al conjunto de prueba.

# %% [markdown]
# #### Buscar mejores parametros con Auto ARIMA (p-d-q)

# %%
# Implementacion Auto Arima

best_pdq = auto_arima(data_1h, trace = True, suppress_warnings = True)
best_pdq.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=11.72 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=44886.781, Time=0.16 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=44502.251, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=44355.432, Time=1.07 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=44884.782, Time=0.09 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=3.06 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=4.53 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=7.37 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=44353.436, Time=0.41 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=inf, Time=0.82 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=43750.780, Time=1.59 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=inf, Time=2.78 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=inf, Time=3.62 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=inf, Time=6.19 sec
#
# ...

# %% [markdown]
# Conforme con los calculos realizados por `Auto ARIMA`, los mejores parametros p-d-q son 0-1-2 respectivamente, los cuales seran aplicados al modelo `ARIMA`.

# %% [markdown]
# #### Prueba de Modelo ARIMA

# %%
# %%time

# Creacion del modelo
y = train

arima_model = ARIMA(y, order = (0, 1, 2))
arima_model = arima_model.fit()
# Out:
# CPU times: user 559 ms, sys: 1.05 s, total: 1.61 s
# Wall time: 1.59 s

# %%
# Prediccion
y_pred = arima_model.get_forecast(len(test))

y_pred_df = y_pred.conf_int()
y_pred_df['predictions'] = arima_model.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df['predictions'] 

plt.figure(figsize = (20,5))
plt.plot(train['num_orders'])
plt.plot(test['num_orders'], color = 'red')
plt.plot(y_pred_out, color = 'black', label = 'ARIMA Predicciones')
plt.legend();

# %%
# Grafico de valores actuales vs predecidos

plt.figure(figsize = (20, 5))
plt.plot(test['num_orders'], color = 'red', label = 'Actuales')
plt.plot(y_pred_out, color = 'blue', label = 'Predecidos')
plt.legend()
plt.title('Valores Actuales vs Valores Predecidos')
plt.show()

# %%
# Calculo RMSE

score_arima = rmse(test, y_pred_out)
score_arima
# Out:
# 63.51176609857585

# %% [markdown]
# El rendimiento de este modelo parece ser deficiente, ya que las predicciones muestran constante el mismo numero, lo que genera un error excesivamente alto, muy por encima del limite asignado al proyecto que es de 48.
#
# Por ello, los pronosticos del model `Auto Arima`, no son confiables, por lo que aplicaran diferentes composiciones de `p-d-q` y se presentaran los mejores resultados, mediante la creacion de un nuevo modelo `ARIMA`.

# %%
# %%time

# Creacion de nuevo modelo ARIMA, con seleccion aleatoria de p-d-q
y = train

arima_model_2 = ARIMA(y, order = (24, 2, 30))
arima_model_2 = arima_model_2.fit()
# Out:
# CPU times: user 3min 44s, sys: 5min 2s, total: 8min 47s
# Wall time: 8min 48s

# %%
# Prediccion

y_pred = arima_model_2.get_forecast(len(test))

y_pred_df = y_pred.conf_int()
y_pred_df['predictions'] = arima_model_2.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df['predictions'] 

plt.figure(figsize=(20,5))
plt.plot(train['num_orders'])
plt.plot(test['num_orders'], color = 'red')
plt.plot(y_pred_out, color = 'black', label = 'ARIMA Predicciones')
plt.legend()

# %%
# Grafico de valores actuales vs predecidos

plt.figure(figsize=(20, 5))
plt.plot(test['num_orders'], color = 'red', label = 'Actuales')
plt.plot(y_pred_out, color = 'blue', label = 'Predecidos')
plt.legend()
plt.title('Valores Actuales vs Valores Predecidos')
plt.show()

# %%
# Calculo de RMSE

score_arima_2 = rmse(test, y_pred_out)
score_arima_2
# Out:
# 45.86150383754118

# %% [markdown]
# En el experimento se usaron varias combinaciones de `p-d-q`, siendo la mas eficiente 24-2-30 respectivamente, por ello el resultado se redujo significativamente, lo que finalmente entrego un `RMSE` menor a 48.

# %% [markdown]
# ### Modelos de Machine Learning

# %% [markdown]
# Para utilizar de forma correcta estos modelo, es necesario crear un nuevo conjunto de datos con caracteristicas adicionales, extraidas de las variables principales (`datetime` y `num_orders`)

# %% [markdown]
# #### Dataset con nuevas caracteristicas

# %%
# Nuevas variables a partir de la columna 'datetime'

data_new = data_1h.copy()

data_new['year'] = data_new.index.year
data_new['month'] = data_new.index.month
data_new['day'] = data_new.index.day
data_new['dayofweek'] = data_new.index.dayofweek
data_new['quarter'] = data_new.index.quarter

data_new.head()
# Out:
#                      num_orders  year  month  day  dayofweek  quarter
# datetime
# 2018-03-01 00:00:00         124  2018      3    1          3        1
# 2018-03-01 01:00:00          85  2018      3    1          3        1
# 2018-03-01 02:00:00          71  2018      3    1          3        1
# 2018-03-01 03:00:00          66  2018      3    1          3        1
# 2018-03-01 04:00:00          43  2018      3    1          3        1

# %%
# Nuevas variables a partir de la columna 'num_orders'

# Crear retardos hasta 6 horas
lags = [1, 2, 3, 4, 5, 6]
for lag in lags:
    data_new[f'lag_{lag}'] = data_new['num_orders'].shift(lag)

# Crear media movil con ventana de 3 a 5 horas
windows = [3, 4, 5]
for window in windows:
    data_new[f'rolling_mean_{window}'] = data_new['num_orders'].rolling(window = window, min_periods = 1).mean()

# Crear suma movil con ventana de 3 a 5 horas
for window in windows:
    data_new[f'rolling_sum_{window}'] = data_new['num_orders'].rolling(window = window, min_periods = 1).sum()

# Calculo media acumulativa
data_new['expanding_mean'] = data_new['num_orders'].expanding(1).mean()

# Eliminar filas de valores nulos
data_new = data_new.dropna()

display(data_new.head())
print('La estructura del nuevo conjunto de datos es ', data_new.shape)
# Out:
#                      num_orders  year  month  day  dayofweek  quarter  lag_1  \
# datetime
# 2018-03-01 06:00:00          12  2018      3    1          3        1    6.0
# 2018-03-01 07:00:00          15  2018      3    1          3        1   12.0
# 2018-03-01 08:00:00          34  2018      3    1          3        1   15.0
# 2018-03-01 09:00:00          69  2018      3    1          3        1   34.0
# 2018-03-01 10:00:00          64  2018      3    1          3        1   69.0
#
#                      lag_2  lag_3  lag_4  lag_5  lag_6  rolling_mean_3  \
# datetime
# 2018-03-01 06:00:00   43.0   66.0   71.0   85.0  124.0       20.333333
# 2018-03-01 07:00:00    6.0   43.0   66.0   71.0   85.0       11.000000
# 2018-03-01 08:00:00   12.0    6.0   43.0   66.0   71.0       20.333333
# 2018-03-01 09:00:00   15.0   12.0    6.0   43.0   66.0       39.333333
# 2018-03-01 10:00:00   34.0   15.0   12.0    6.0   43.0       55.666667
#
# ...

# %% [markdown]
# #### Particion del nuevo dataset

# %%
features = data_new.drop('num_orders', axis = 1)
target = data_new['num_orders']

features_train, features_test, target_train, target_test = train_test_split(features, target, shuffle = False, test_size = 0.1, random_state = seed)

# %%
# Estructura de los conjuntos de datos

print(features_train.shape)
print(features_test.shape)
print(target_train.shape)
print(target_test.shape)
# Out:
# (3969, 18)
# (441, 18)
# (3969,)
# (441,)

# %% [markdown]
# ### Linear Regression
#
# Linear Regression, es el modelo referencial del proyecto

# %%
# %%time
# Aplicacion de funcion sin ajuste de hiperparametros

train_model_no_tuning(LinearRegression(), features_train, target_train)
# Out:
# CPU times: user 69.5 ms, sys: 106 ms, total: 176 ms
# Wall time: 117 ms
# 6.93958553920683e-14

# %%
# %%time
# Aplicacion de funcion con ajuste de hiperparametros

param_distributions_lr = {'fit_intercept': [True, False],
                       'copy_X': [True, False]}

train_model_tuning(LinearRegression(), features_train, target_train, param_distributions_lr)
# Out:
# Best Estimator: LinearRegression()
# Best Parameters: {'fit_intercept': True, 'copy_X': True}
# Best RMSE: 6.93958553920683e-14
# CPU times: user 331 ms, sys: 889 ms, total: 1.22 s
# Wall time: 1.21 s

# %% [markdown]
# El modelo entrego puntuaciones de error demasiado pequeñas, muy cercanas a 0, y con resultados mejores en el modelo ajustado; sin embargo, una puntuacion tan notable dar puede generar sobreajuste, no obstante, hasta el momento no hay errores en el codigo, por lo que se efectuara, la evaluacion del modelo con los datos de prueba.

# %%
# %%time
# Prueba con conjunto de prueba

lr = LinearRegression(fit_intercept = True, copy_X = True).fit(features_train, target_train)
lr_pred = lr.predict(features_test)
lr_rmse = rmse(target_test, lr_pred)
lr_rmse
# Out:
# CPU times: user 9.68 ms, sys: 9.51 ms, total: 19.2 ms
# Wall time: 58.6 ms
# 8.026331347311161e-14

# %%
# Aplicacion de funcion 'graph_real_predict'

graph_real_predict(lr_pred, 'red', 'green')

# %% [markdown]
# La puntuacion en el conjunto de prueba es tan pequeña como la obtenida en entrenamiento, y el grafico se alinea correctamente, esto apunta, a que los valores predecidos concuerdan con estrechamente con los valores reales, lo que insinua un modelo que excelente rendimiento, que incluso es muy bueno para ser cierto.

# %% [markdown]
# ### Decision Tree Regressor

# %%
# %%time
# Aplicacion de funcion sin ajuste de hiperparametros

train_model_no_tuning(DecisionTreeRegressor(random_state = seed), features_train, target_train)
# Out:
# CPU times: user 166 ms, sys: 0 ns, total: 166 ms
# Wall time: 185 ms
# 15.921089369514528

# %% [markdown]
# El modelo se desempeña bastante bien, ya que el valor del `RMSE` esta muy distante de 48, por lo que se intentara ajustar sus hiperparametros

# %%
# %%time
# Aplicacion de funcion con ajuste de hiperparametros

param_distributions_dtr = {'max_depth': [None, 5, 10, 20],
                           'min_samples_split': [2, 5, 10],
                           'min_samples_leaf': [1, 2, 4],
                           'max_features': ['auto', 'sqrt', 'log2', None],
                           'splitter': ['best', 'random'],
                           'random_state': [seed]}

train_model_tuning(DecisionTreeRegressor(), features_train, target_train, param_distributions_dtr)
# Out:
# Best Estimator: DecisionTreeRegressor(max_depth=20, min_samples_leaf=4, min_samples_split=5,
#                       random_state=200)
# Best Parameters: {'splitter': 'best', 'random_state': 200, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': None, 'max_depth': 20}
# Best RMSE: 14.891310035921157
# CPU times: user 625 ms, sys: 0 ns, total: 625 ms
# Wall time: 698 ms

# %% [markdown]
# El rendimiento es mejor despues de los ajustes, por ello se aplicara al conjunto de prueba.

# %%
# %%time
# Prueba con conjunto de prueba

dtr = DecisionTreeRegressor(splitter = 'best', random_state = seed, min_samples_split = 5, 
                           min_samples_leaf = 4, max_features = None, max_depth = 20).fit(features_train, target_train)
dtr_pred = dtr.predict(features_test)
dtr_rmse = rmse(target_test, dtr_pred)
dtr_rmse
# Out:
# CPU times: user 38.7 ms, sys: 0 ns, total: 38.7 ms
# Wall time: 40.5 ms
# 37.52343262446122

# %%
# Aplicacion de funcion 'graph_real_predict'

graph_real_predict(dtr_pred, 'blue', 'yellow')

# %% [markdown]
# La puntuacion es significativamente superior a la obtenida en el entrenamiento, aunque sigue siendo menor al limite solicitado.

# %% [markdown]
# ### Random Forest Regressor

# %%
# %%time
# Aplicacion de funcion sin ajuste de hiperparametros

train_model_no_tuning(RandomForestRegressor(random_state = seed), features_train, target_train)
# Out:
# CPU times: user 9.39 s, sys: 0 ns, total: 9.39 s
# Wall time: 9.57 s
# 10.057418688754657

# %% [markdown]
# Se obtuvo una puntuacion bastante mejor que en el modelo `LinearRegression`, por lo que se aplicara ajuste de sus hiperparametros

# %%
# %%time
# Aplicacion de funcion con ajuste de hiperparametros

# Se utilizan valores definidos para controlar la aleatoriedad
param_distributions_rfr = {'n_estimators': [50, 100, 150, 200],
                           'max_depth': [None, 5, 10, 20],
                           'min_samples_split': [2, 5, 10],
                           'min_samples_leaf': [1, 2, 4],
                           'max_features': ['auto', 'sqrt', 'log2', None],
                           'bootstrap': [True, False],
                           'random_state': [seed]}


train_model_tuning(RandomForestRegressor(), features_train, target_train, param_distributions_rfr)
# Out:
# Best Estimator: RandomForestRegressor(max_features=None, min_samples_leaf=4,
#                       min_samples_split=5, n_estimators=200, random_state=200)
# Best Parameters: {'random_state': 200, 'n_estimators': 200, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': None, 'max_depth': None, 'bootstrap': True}
# Best RMSE: 10.380926845248439
# CPU times: user 46.2 s, sys: 0 ns, total: 46.2 s
# Wall time: 47.3 s

# %% [markdown]
# El error es mayor luego de los ajustes, por ello, la prueba para el conjunto de prueba sera con ajuste de hiperparametros

# %%
# %%time
# Prueba con el conjunto de prueba

rfr = RandomForestRegressor().fit(features_train, target_train)
rfr_pred = rfr.predict(features_test)
rfr_rmse = rmse(target_test, rfr_pred)
rfr_rmse
# Out:
# CPU times: user 2.4 s, sys: 0 ns, total: 2.4 s
# Wall time: 2.69 s
# 30.439731804593826

# %%
# Aplicacion de funcion 'graph_real_predict'

graph_real_predict(rfr_pred, 'grey', 'orange')

# %% [markdown]
# El resultado obtenido del `RMSE` es mejor en comparacion con el modelo `Decision Tree Regressor`

# %% [markdown]
# ### XGBoost Regressor

# %%
# %%time
# Aplicacion de funcion sin ajuste de hiperparametros

train_model_no_tuning(XGBRegressor(), features_train, target_train)
# Out:
# CPU times: user 27.5 s, sys: 0 ns, total: 27.5 s
# Wall time: 27.7 s
# 8.283362912215134

# %% [markdown]
# La puntuacion es mejor que los modelos anteriores.

# %%
# %%time
# Aplicacion de funcion con ajuste de hiperparametros

param_distributions_xgbr = {'max_depth'    : sp_randInt(5, 10),
                            'n_estimators' : sp_randInt(50, 100),
                            'learning_rate': sp_randFloat(),
                            'subsample'    : sp_randFloat()}

train_model_tuning(XGBRegressor(), features_train, target_train, param_distributions_xgbr)
# Out:
# Best Estimator: XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.3331234825107796,
#              max_delta_step=0, max_depth=7, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=56, n_jobs=4,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=0.6796418342262324,
#              tree_method='exact', validate_parameters=1, verbosity=None)
# Best Parameters: {'learning_rate': 0.3331234825107796, 'max_depth': 7, 'n_estimators': 56, 'subsample': 0.6796418342262324}
# Best RMSE: 8.86285567764892
# CPU times: user 2min 5s, sys: 0 ns, total: 2min 5s
# Wall time: 2min 10s

# %% [markdown]
#  El resultado es mejor aun, por lo que se aplicara al conjunto de prueba.

# %%
# %%time
# Prueba con el conjunto de prueba

xgbr = XGBRegressor(learning_rate = 0.09702613049463282, max_depth=8, n_estimators = 73,
                    subsample = 0.566905715389558).fit(features_train, target_train)
xgbr_pred = xgbr.predict(features_test)
xgbr_rmse = rmse(target_test, xgbr_pred)
xgbr_rmse
# Out:
# CPU times: user 1.54 s, sys: 0 ns, total: 1.54 s
# Wall time: 1.59 s
# 29.03825502844629

# %%
# Aplicacion de funcion 'graph_real_predict'

graph_real_predict(xgbr_pred, 'pink', 'purple')

# %% [markdown]
# La puntuacion es mayor a la obtenida en el entrenamiento, pero aun esta dentro de los estandares permitidos del proyecto.

# %% [markdown]
# ### LightGBM Regressor

# %%
# %%time
# Aplicacion de funcion sin ajuste hiperparametros

train_model_no_tuning(LGBMRegressor(), features_train, target_train)
# Out:
# CPU times: user 1.81 s, sys: 0 ns, total: 1.81 s
# Wall time: 1.82 s
# 7.549663277024969

# %%
# %%time
# Aplicacion de funcion con ajuste de hiperparametros

param_distributions_lgbmr = {'max_depth'    : sp_randInt(5, 10),
                             'n_estimators' : sp_randInt(50, 100),
                             'learning_rate': sp_randFloat(),
                             'subsample'    : sp_randFloat()}

train_model_tuning(LGBMRegressor(), features_train, target_train, param_distributions_lgbmr)
# Out:
# Best Estimator: LGBMRegressor(learning_rate=0.32934810381054125, max_depth=9, n_estimators=97,
#               subsample=0.09866668263695522)
# Best Parameters: {'learning_rate': 0.32934810381054125, 'max_depth': 9, 'n_estimators': 97, 'subsample': 0.09866668263695522}
# Best RMSE: 8.310442990574822
# CPU times: user 7.84 s, sys: 0 ns, total: 7.84 s
# Wall time: 7.81 s

# %% [markdown]
# Igual que otro modelo probado anteriormente, este modelo tiene mejor desempeño sin ajuste de hiperparametros, el cual supera al `XGBoost Regressor`, por lo que se aplicara el modelo sin ajuste de hiperparametros al conjunto de prueba.

# %%
# %%time
# Prueba con el conjunto de prueba

lgbmr = LGBMRegressor().fit(features_train, target_train)
lgbmr_pred = lgbmr.predict(features_test)
lgbmr_rmse = rmse(target_test, lgbmr_pred)
lgbmr_rmse
# Out:
# CPU times: user 348 ms, sys: 0 ns, total: 348 ms
# Wall time: 390 ms
# 31.733142032211855

# %%
# Aplicacion de funcion 'graph_real_predict'

graph_real_predict(lgbmr_pred, 'brown', 'skyblue')

# %% [markdown]
# Evidentemente, los resultados del conjunto de prueba ratifican que el modelo `LightGBM Regressor`, no es superior a `XGB Regressor`.

# %% [markdown]
# ### Catboost Regressor

# %%
# %%time
# Aplicando funcion sin ajuste de hiperparametros

# Uso de verbose = 500 para resumir los resultados
train_model_no_tuning(CatBoostRegressor(verbose = 500), features_train, target_train)
# Out:
# Learning rate set to 0.049142
# 0:	learn: 37.7825232	total: 49.8ms	remaining: 49.7s
# 500:	learn: 2.5841455	total: 1.35s	remaining: 1.34s
# 999:	learn: 1.1111950	total: 2.63s	remaining: 0us
# Learning rate set to 0.049142
# 0:	learn: 38.2840983	total: 3.98ms	remaining: 3.98s
# 500:	learn: 2.7673864	total: 1.36s	remaining: 1.35s
# 999:	learn: 1.2075154	total: 2.57s	remaining: 0us
# Learning rate set to 0.049142
# 0:	learn: 38.4897626	total: 3.32ms	remaining: 3.32s
# 500:	learn: 2.8600053	total: 1.2s	remaining: 1.2s
# 999:	learn: 1.1698833	total: 2.42s	remaining: 0us
# Learning rate set to 0.049142
# 0:	learn: 38.4929570	total: 2.9ms	remaining: 2.9s
# 500:	learn: 2.8161517	total: 1.2s	remaining: 1.19s
# 999:	learn: 1.2022913	total: 2.4s	remaining: 0us
# Learning rate set to 0.049145
# 0:	learn: 33.3114076	total: 3.49ms	remaining: 3.49s
# 500:	learn: 1.9265304	total: 1.18s	remaining: 1.18s
# 999:	learn: 0.9493189	total: 2.33s	remaining: 0us
# ...

# %% [markdown]
# El modelo `CatBoost Regressor` evidencia ser el mejor modelo, solo superado por `Linear Regression`.

# %%
# %%time
# Aplicacion de funcion con ajuste de hiperparametros

param_distributions_cbr = {'max_depth'    : sp_randInt(5, 10),
                           'n_estimators' : sp_randInt(50, 100),
                           'learning_rate': sp_randFloat(),
                           'subsample'    : sp_randFloat()}

train_model_tuning(CatBoostRegressor(verbose = 500), features_train, target_train, param_distributions_cbr)
# Out:
# 0:	learn: 26.5331732	total: 1.85ms	remaining: 97.9ms
# 53:	learn: 4.1092336	total: 83.8ms	remaining: 0us
# 0:	learn: 25.6331722	total: 1.85ms	remaining: 98.2ms
# 53:	learn: 3.5967343	total: 84.7ms	remaining: 0us
# 0:	learn: 25.8724520	total: 1.78ms	remaining: 94.4ms
# 53:	learn: 3.9612850	total: 85.5ms	remaining: 0us
# 0:	learn: 25.8757079	total: 1.96ms	remaining: 104ms
# 53:	learn: 3.8763745	total: 84.1ms	remaining: 0us
# 0:	learn: 21.9470801	total: 2.34ms	remaining: 124ms
# 53:	learn: 3.2288716	total: 95.6ms	remaining: 0us
# 0:	learn: 34.1678394	total: 2.96ms	remaining: 186ms
# 0:	learn: 33.7278838	total: 3.46ms	remaining: 218ms
# Custom logger is already specified. Specify more than one logger at same time is not thread safe.
# 63:	learn: 13.5611656	total: 143ms	remaining: 0us
# 0:	learn: 32.7926113	total: 2.86ms	remaining: 180ms
# 63:	learn: 13.0936595	total: 139ms	remaining: 0us
# 0:	learn: 33.6275911	total: 3.2ms	remaining: 202ms
# ...

# %% [markdown]
#  Los ajustes no implican una mejor puntuacion.

# %%
# %%time
# Prueba con el conjunto de prueba

cbr = CatBoostRegressor(verbose = 500).fit(features_train, target_train)
cbr_pred = cbr.predict(features_test)
cbr_rmse = rmse(target_test, cbr_pred)
cbr_rmse
# Out:
# Learning rate set to 0.050906
# 0:	learn: 37.5193981	total: 3.01ms	remaining: 3.01s
# 500:	learn: 2.4049679	total: 1.24s	remaining: 1.24s
# 999:	learn: 1.1072598	total: 2.5s	remaining: 0us
# CPU times: user 2.53 s, sys: 0 ns, total: 2.53 s
# Wall time: 2.64 s
# 32.06741824487543

# %%
# Aplicacion de funcion 'graph_real_predict'

graph_real_predict(cbr_pred, 'black', 'lightgreen')

# %% [markdown]
# Aunque tiene el mejor resultado de entrenamiento, entre todos los modelos, pero el conjunto de prueba demuestra un rendimiento peor, al resto de los modelos.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Elaboracion de un cuadro comparativo de los puntajes obtenidos para RMSE en cada modelo.

# %%
summary = pd.DataFrame(data = {'Modelo':['ARIMA', 'Linear Regression', 'Decision Tree Regressor', 'Random Forest Regressor',
                                         'XGBoost Regressor', 'LightGBM Regressor', 'CatBoost Regressor'],
                               'RMSE':[score_arima_2, lr_rmse, dtr_rmse, rfr_rmse, xgbr_rmse, lgbmr_rmse, 
                                       cbr_rmse]}).set_index('Modelo')
pd.set_option('display.float_format', lambda x: '%.5f' % x)
summary
# Out:
#                             RMSE
# Modelo
# ARIMA                   45.86150
# Linear Regression        0.00000
# Decision Tree Regressor 37.52343
# Random Forest Regressor 30.43973
# XGBoost Regressor       29.03826
# LightGBM Regressor      31.73314
# CatBoost Regressor      32.06742

# %% [markdown]
# Los resultados de las pruebas en diversos modelos, indican que los modelos de Machine Learning tienen un mejor desempeño en la prediccion en comparacion con modelos tradicionales, como lo es `ARIMA`. Los modelos de Machine Learning lograron puntajes dentro sw loa estandares estaablecidos para esta tarea, es decir, por debajo de 48.
#
# Entre los modelos de Machine Learning, la mejor opcion es `Linear Regression`, con un puntaje de 0, lo que indica que el modelo tuvo un desempeño excepcional en la prediccion de los resultados. Sorprendentemente, este modelo de `Linear Regression`, a pesar de su simplicidad, supero a otros modelos mas complejos.
#
# En la segunda posicion, obtuvimos el modelo `XGBoost Regressor`, con un puntaje de 29 en el conjunto de prueba.

# %% [markdown]
# # Lista de revisión

# %% [markdown]
# - [x]
# Jupyter Notebook está abierto.
# - [ ]  El código no tiene errores
# - [ ]  Las celdas con el código han sido colocadas en el orden de ejecución.
# - [ ]
# Los datos han sido descargados y preparados.
# - [ ]  Se ha realizado el paso 2: los datos han sido analizados
# - [ ]  Se entrenó el modelo y se seleccionaron los hiperparámetros
# - [ ]  Se han evaluado los modelos. Se expuso una conclusión
# - [ ] La *RECM* para el conjunto de prueba no es más de 48
