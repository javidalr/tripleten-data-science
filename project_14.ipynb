# %% [markdown]
# # Hola Javier! <a class="tocSkip"></a>
#
# Mi nombre es Oscar Flores y tengo el gusto de revisar tu proyecto. Si tienes algún comentario que quieras agregar en tus respuestas te puedes referir a mi como Oscar, no hay problema que me trates de tú.
#
# Si veo un error en la primera revisión solamente lo señalaré y dejaré que tú encuentres de qué se trata y cómo arreglarlo. Debo prepararte para que te desempeñes como especialista en Data, en un trabajo real, el responsable a cargo tuyo hará lo mismo. Si aún tienes dificultades para resolver esta tarea, te daré indicaciones más precisas en una siguiente iteración.
#
# Te dejaré mis comentarios más abajo - **por favor, no los muevas, modifiques o borres**
#
# Comenzaré mis comentarios con un resumen de los puntos que están bien, aquellos que debes corregir y aquellos que puedes mejorar. Luego deberás revisar todo el notebook para leer mis comentarios, los cuales estarán en rectángulos de color verde, amarillo o rojo como siguen:
#
# <div class="alert alert-block alert-success">
# <b>Comentario de Reviewer</b> <a class="tocSkip"></a>
#
# Muy bien! Toda la respuesta fue lograda satisfactoriamente.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario de Reviewer</b> <a class="tocSkip"></a>
#
# Existen detalles a mejorar. Existen recomendaciones.
# </div>
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentario de Reviewer</b> <a class="tocSkip"></a>
#
# Se necesitan correcciones en el bloque. El trabajo no puede ser aceptado con comentarios en rojo sin solucionar.
# </div>
#
# Cualquier comentario que quieras agregar entre iteraciones de revisión lo puedes hacer de la siguiente manera:
#
# <div class="alert alert-block alert-info">
# <b>Respuesta estudiante.</b> <a class="tocSkip"></a>
# </div>
#
# Mucho éxito en el proyecto!

# %% [markdown]
# ## Resumen de la revisión 1 <a class="tocSkip"></a>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor</b> <a class="tocSkip"></a>
#
# Buen trabajo Javier! Has completado correctamente todo lo necesario del notebook. No tengo comentarios de corrección, está aprobado. Felicitaciones por completar el notebook en la primera revisión.
#
# Saludos!
#
# </div>

# %% [markdown]
# ----

# %% [markdown]
# <h1><center>Film Junky Union - Analisis de Sentimientos en Peliculas </center></h1>

# %% [markdown]
# ----

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Descripcipción-del-proyecto" data-toc-modified-id="Descripcipción-del-proyecto-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Descripcipción del proyecto</a></span><ul class="toc-item"><li><span><a href="#Problema-de-negocio" data-toc-modified-id="Problema-de-negocio-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Problema de negocio</a></span></li><li><span><a href="#Propuesta-del-proyecto" data-toc-modified-id="Propuesta-del-proyecto-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Propuesta del proyecto</a></span></li></ul></li><li><span><a href="#Preprocesamiento-de-datos" data-toc-modified-id="Preprocesamiento-de-datos-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Preprocesamiento de datos</a></span><ul class="toc-item"><li><span><a href="#Descripcion-de-los-datos" data-toc-modified-id="Descripcion-de-los-datos-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Descripcion de los datos</a></span></li><li><span><a href="#Ambiente-y-librerias" data-toc-modified-id="Ambiente-y-librerias-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Ambiente y librerias</a></span></li><li><span><a href="#Funciones" data-toc-modified-id="Funciones-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Funciones</a></span></li><li><span><a href="#Carga-y-lectura-de-datos" data-toc-modified-id="Carga-y-lectura-de-datos-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Carga y lectura de datos</a></span></li></ul></li><li><span><a href="#EDA" data-toc-modified-id="EDA-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>EDA</a></span></li><li><span><a href="#Procedimiento-de-evaluación" data-toc-modified-id="Procedimiento-de-evaluación-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Procedimiento de evaluación</a></span></li><li><span><a href="#Normalización" data-toc-modified-id="Normalización-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Normalización</a></span></li><li><span><a href="#División-entrenamiento-/-prueba" data-toc-modified-id="División-entrenamiento-/-prueba-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>División entrenamiento / prueba</a></span></li><li><span><a href="#Trabajar-con-modelos" data-toc-modified-id="Trabajar-con-modelos-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Trabajar con modelos</a></span><ul class="toc-item"><li><span><a href="#Modelo-0---Constante" data-toc-modified-id="Modelo-0---Constante-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Modelo 0 - Constante</a></span></li><li><span><a href="#Modelo-1---NLTK,-TF-IDF-y-Logistic-Regression" data-toc-modified-id="Modelo-1---NLTK,-TF-IDF-y-Logistic-Regression-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Modelo 1 - NLTK, TF-IDF y Logistic Regression</a></span><ul class="toc-item"><li><span><a href="#Implementar-metodo-TF-IDF-y-preprocesamiento-NLTK" data-toc-modified-id="Implementar-metodo-TF-IDF-y-preprocesamiento-NLTK-7.2.1"><span class="toc-item-num">7.2.1&nbsp;&nbsp;</span>Implementar metodo TF-IDF y preprocesamiento NLTK</a></span></li><li><span><a href="#Logistic-Regression---NLTK" data-toc-modified-id="Logistic-Regression---NLTK-7.2.2"><span class="toc-item-num">7.2.2&nbsp;&nbsp;</span>Logistic Regression - NLTK</a></span></li><li><span><a href="#Prueba-modelo-Logistic-Regression---NLTK-con-nuevo-conjunto-de-prueba" data-toc-modified-id="Prueba-modelo-Logistic-Regression---NLTK-con-nuevo-conjunto-de-prueba-7.2.3"><span class="toc-item-num">7.2.3&nbsp;&nbsp;</span>Prueba modelo Logistic Regression - NLTK con nuevo conjunto de prueba</a></span></li></ul></li><li><span><a href="#Modelo-2---spaCy,-TF-IDF-y-Logistic-Regression" data-toc-modified-id="Modelo-2---spaCy,-TF-IDF-y-Logistic-Regression-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Modelo 2 - spaCy, TF-IDF y Logistic Regression</a></span><ul class="toc-item"><li><span><a href="#Implementar-metodo-TF-IDF-y-preprocesamiento-SpaCy" data-toc-modified-id="Implementar-metodo-TF-IDF-y-preprocesamiento-SpaCy-7.3.1"><span class="toc-item-num">7.3.1&nbsp;&nbsp;</span>Implementar metodo TF-IDF y preprocesamiento SpaCy</a></span></li><li><span><a href="#Logistic-Regression---SpaCy" data-toc-modified-id="Logistic-Regression---SpaCy-7.3.2"><span class="toc-item-num">7.3.2&nbsp;&nbsp;</span>Logistic Regression - SpaCy</a></span></li><li><span><a href="#Prueba-modelo-Logistic-Regression---SpaCy-con-nuevo-conjunto-de-prueba" data-toc-modified-id="Prueba-modelo-Logistic-Regression---SpaCy-con-nuevo-conjunto-de-prueba-7.3.3"><span class="toc-item-num">7.3.3&nbsp;&nbsp;</span>Prueba modelo Logistic Regression - SpaCy con nuevo conjunto de prueba</a></span></li></ul></li><li><span><a href="#Modelo-4---NLTK,-TF-IDF-y-LGBM-Classifier" data-toc-modified-id="Modelo-4---NLTK,-TF-IDF-y-LGBM-Classifier-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Modelo 4 - NLTK, TF-IDF y LGBM Classifier</a></span><ul class="toc-item"><li><span><a href="#Implementar-metodo-TF-IDF-y-preprocesamiento-NLTK" data-toc-modified-id="Implementar-metodo-TF-IDF-y-preprocesamiento-NLTK-7.4.1"><span class="toc-item-num">7.4.1&nbsp;&nbsp;</span>Implementar metodo TF-IDF y preprocesamiento NLTK</a></span></li><li><span><a href="#LightGBM-Calssifier---NLTK" data-toc-modified-id="LightGBM-Calssifier---NLTK-7.4.2"><span class="toc-item-num">7.4.2&nbsp;&nbsp;</span>LightGBM Calssifier - NLTK</a></span></li><li><span><a href="#Prueba-modelo-LightGBM-Classifier---NLTK-con-nuevo-conjunto-de-prueba" data-toc-modified-id="Prueba-modelo-LightGBM-Classifier---NLTK-con-nuevo-conjunto-de-prueba-7.4.3"><span class="toc-item-num">7.4.3&nbsp;&nbsp;</span>Prueba modelo LightGBM Classifier - NLTK con nuevo conjunto de prueba</a></span></li></ul></li><li><span><a href="#Modelo-4---spaCy,-TF-IDF-y-LGBM-Classifier" data-toc-modified-id="Modelo-4---spaCy,-TF-IDF-y-LGBM-Classifier-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Modelo 4 - spaCy, TF-IDF y LGBM Classifier</a></span><ul class="toc-item"><li><span><a href="#Implementar-metodo-TF-IDF-y-preprocesamiento-SpaCy" data-toc-modified-id="Implementar-metodo-TF-IDF-y-preprocesamiento-SpaCy-7.5.1"><span class="toc-item-num">7.5.1&nbsp;&nbsp;</span>Implementar metodo TF-IDF y preprocesamiento SpaCy</a></span></li><li><span><a href="#LightGBM-Classifier---SpaCy" data-toc-modified-id="LightGBM-Classifier---SpaCy-7.5.2"><span class="toc-item-num">7.5.2&nbsp;&nbsp;</span>LightGBM Classifier - SpaCy</a></span></li><li><span><a href="#Prueba-modelo-LightGBM-Classifier---SpaCy-con-nuevo-conjunto-de-prueba" data-toc-modified-id="Prueba-modelo-LightGBM-Classifier---SpaCy-con-nuevo-conjunto-de-prueba-7.5.3"><span class="toc-item-num">7.5.3&nbsp;&nbsp;</span>Prueba modelo LightGBM Classifier - SpaCy con nuevo conjunto de prueba</a></span></li></ul></li><li><span><a href="#Modelo-5---NLTK,-TF-IDF-y-XGBoost-Classifier" data-toc-modified-id="Modelo-5---NLTK,-TF-IDF-y-XGBoost-Classifier-7.6"><span class="toc-item-num">7.6&nbsp;&nbsp;</span>Modelo 5 - NLTK, TF-IDF y XGBoost Classifier</a></span><ul class="toc-item"><li><span><a href="#Implementar-metodo-TF-IDF-y-preprocesamiento-NLTK" data-toc-modified-id="Implementar-metodo-TF-IDF-y-preprocesamiento-NLTK-7.6.1"><span class="toc-item-num">7.6.1&nbsp;&nbsp;</span>Implementar metodo TF-IDF y preprocesamiento NLTK</a></span></li><li><span><a href="#XGBoost-Classifier---NLTK" data-toc-modified-id="XGBoost-Classifier---NLTK-7.6.2"><span class="toc-item-num">7.6.2&nbsp;&nbsp;</span>XGBoost Classifier - NLTK</a></span></li><li><span><a href="#Prueba-modelo-XGBoost-Classifier---NLTK-con-nuevo-conjunto-de-prueba" data-toc-modified-id="Prueba-modelo-XGBoost-Classifier---NLTK-con-nuevo-conjunto-de-prueba-7.6.3"><span class="toc-item-num">7.6.3&nbsp;&nbsp;</span>Prueba modelo XGBoost Classifier - NLTK con nuevo conjunto de prueba</a></span></li></ul></li><li><span><a href="#Modelo-6---SpaCy,-TF-IDF-y-XGBoost-Classifier" data-toc-modified-id="Modelo-6---SpaCy,-TF-IDF-y-XGBoost-Classifier-7.7"><span class="toc-item-num">7.7&nbsp;&nbsp;</span>Modelo 6 - SpaCy, TF-IDF y XGBoost Classifier</a></span><ul class="toc-item"><li><span><a href="#Implementar-metodo-TF-IDF-y-preprocesamiento-SpaCy" data-toc-modified-id="Implementar-metodo-TF-IDF-y-preprocesamiento-SpaCy-7.7.1"><span class="toc-item-num">7.7.1&nbsp;&nbsp;</span>Implementar metodo TF-IDF y preprocesamiento SpaCy</a></span></li><li><span><a href="#XGBoost-Classifier---SpaCy" data-toc-modified-id="XGBoost-Classifier---SpaCy-7.7.2"><span class="toc-item-num">7.7.2&nbsp;&nbsp;</span>XGBoost Classifier - SpaCy</a></span></li><li><span><a href="#Prueba-modelo-XGBoost-Classifier---SpaCy-con-nuevo-conjunto-de-prueba" data-toc-modified-id="Prueba-modelo-XGBoost-Classifier---SpaCy-con-nuevo-conjunto-de-prueba-7.7.3"><span class="toc-item-num">7.7.3&nbsp;&nbsp;</span>Prueba modelo XGBoost Classifier - SpaCy con nuevo conjunto de prueba</a></span></li></ul></li><li><span><a href="#Modelo-7---NLTK,-TF-IDF-y-CatBoost-Classifier" data-toc-modified-id="Modelo-7---NLTK,-TF-IDF-y-CatBoost-Classifier-7.8"><span class="toc-item-num">7.8&nbsp;&nbsp;</span>Modelo 7 - NLTK, TF-IDF y CatBoost Classifier</a></span><ul class="toc-item"><li><span><a href="#Implementar-metodo-TF-IDF-y-preprocesamiento-NLTK" data-toc-modified-id="Implementar-metodo-TF-IDF-y-preprocesamiento-NLTK-7.8.1"><span class="toc-item-num">7.8.1&nbsp;&nbsp;</span>Implementar metodo TF-IDF y preprocesamiento NLTK</a></span></li><li><span><a href="#CatBoost-Classifier---NLTK" data-toc-modified-id="CatBoost-Classifier---NLTK-7.8.2"><span class="toc-item-num">7.8.2&nbsp;&nbsp;</span>CatBoost Classifier - NLTK</a></span></li><li><span><a href="#Prueba-modelo-CatBoost-Classifier---NLTK-con-nuevo-conjunto-de-prueba" data-toc-modified-id="Prueba-modelo-CatBoost-Classifier---NLTK-con-nuevo-conjunto-de-prueba-7.8.3"><span class="toc-item-num">7.8.3&nbsp;&nbsp;</span>Prueba modelo CatBoost Classifier - NLTK con nuevo conjunto de prueba</a></span></li></ul></li><li><span><a href="#Modelo-8---SpaCy,-TF-IDF-y-CatBoost-Classifier" data-toc-modified-id="Modelo-8---SpaCy,-TF-IDF-y-CatBoost-Classifier-7.9"><span class="toc-item-num">7.9&nbsp;&nbsp;</span>Modelo 8 - SpaCy, TF-IDF y CatBoost Classifier</a></span><ul class="toc-item"><li><span><a href="#Implementar-metodo-TF-IDF-y-preprocesamiento-SpaCy" data-toc-modified-id="Implementar-metodo-TF-IDF-y-preprocesamiento-SpaCy-7.9.1"><span class="toc-item-num">7.9.1&nbsp;&nbsp;</span>Implementar metodo TF-IDF y preprocesamiento SpaCy</a></span></li><li><span><a href="#CatBoost-Classifier---SpaCy" data-toc-modified-id="CatBoost-Classifier---SpaCy-7.9.2"><span class="toc-item-num">7.9.2&nbsp;&nbsp;</span>CatBoost Classifier - SpaCy</a></span></li><li><span><a href="#Prueba-modelo-CatBoost-Classifier---SpaCy-con-nuevo-conjunto-de-prueba" data-toc-modified-id="Prueba-modelo-CatBoost-Classifier---SpaCy-con-nuevo-conjunto-de-prueba-7.9.3"><span class="toc-item-num">7.9.3&nbsp;&nbsp;</span>Prueba modelo CatBoost Classifier - SpaCy con nuevo conjunto de prueba</a></span></li></ul></li></ul></li><li><span><a href="#Conclusiones" data-toc-modified-id="Conclusiones-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Conclusiones</a></span></li></ul></div>

# %% [markdown]
# ## Descripcipción del proyecto

# %% [markdown]
# ### Problema de negocio

# %% [markdown]
# Film Junky Union, una nueva comunidad vanguardista para los aficionados de las películas clásicas, está desarrollando un sistema para filtrar y categorizar reseñas de películas. Tu objetivo es entrenar un modelo para detectar las críticas negativas de forma automática. Para lograrlo, utilizarás un conjunto de datos de reseñas de películas de IMDB con leyendas de polaridad para construir un modelo para clasificar las reseñas positivas y negativas. Este deberá alcanzar un valor F1 de al menos 0.85.

# %% [markdown]
# ### Propuesta del proyecto

# %% [markdown]
# El proyecto se compondra de las siguientes etapas.
#
# - Carga e inspeccion de datos.
#
#
# - Preprocesamiento de los datos.
#
#
# - Analisis explotratorio de datos (EDA) y tratamiento de clases.
#
#
# - Preparacion de datos para el modelo.
#
#
# - Entrenamiento de al menos 3 modelos en el conjunto de prueba existente.
#
#
# - Redaccion de reseñas adiciconales y su clasificacion utilizando todos los modelos.
#
#
# - Analisis y comparacion de los resultados con el conjunto de prueba de los modelos, con analisis de las diferencias observadas.

# %% [markdown]
# ## Preprocesamiento de datos

# %% [markdown]
# ### Descripcion de los datos

# %% [markdown]
# Los datos se almacenan en el archivo `imdb_reviews.tsv`.
#
# Los datos fueron proporcionados por Andrew L. Maas, Raymond E. Daly, Peter T. Pham, Dan Huang, Andrew Y. Ng, y Christopher Potts. (2011). Learning Word Vectors for Sentiment Analysis. La Reunión Anual 49 de la Asociación de Lingüística Computacional (ACL 2011).
#
# Aquí se describen los campos seleccionados:
#
# - `review`: el texto de la reseña
# - `pos`: el objetivo, '0' para negativo y '1' para positivo
# - `ds_part`: 'entrenamiento'/'prueba' para la parte de entrenamiento/prueba del conjunto de datos, respectivamente.
#
# Estas son las variables prioncipales para el desarrollo del proyecto, pero es necesario indicar que el conjunto de datos se compone tambien con otros campos.

# %% [markdown]
# ### Ambiente y librerias

# %%
# Importando librerias

import math

import numpy as np
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

import sklearn.metrics as metrics
from sklearn.dummy import DummyClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

import nltk
from nltk.corpus import stopwords as nltk_stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

import re
import spacy

from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
# %config InlineBackend.figure_format = 'png'

# Better quality graphics on HiDPI screens
# %config InlineBackend.figure_format = 'retina'

plt.style.use('seaborn')

# Semilla de aleatoriedad
seed = 200

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor</b> <a class="tocSkip"></a>
#
# Muy bien al importar y configurar los ambientes en un inicio, da más claridad de lo que se utilizará en el notebook
#
# </div>

# %% [markdown]
# ### Funciones

# %%
# 1.Contexto general del conjunto de datos

def info_data(data):
    print('1. Tabla de datos')
    display(data.sample(10))
    print('='*100)
    print()

    print('2. Registros y variables')
    print()
    print('Registros: ', data.shape[0])
    print()
    print('Variables: ', data.shape[1])
    print('='*100)
    print()

    print('3. Resumen general del dataset')
    print(data.info())
    print('='*100)
    print()

    print('4. Resumen estadistico del dataset')
    print()
    print(data.describe())
    print('='*100)
    print()

    print('5. Valores duplicados por variable')
    print()
    print(data.duplicated().sum())
    print('='*100)
    print()

    print('6. Valores ausentes por variable')
    print()
    print(data.isna().sum())
    print('='*100)
    print()

# %% [markdown]
# ### Carga y lectura de datos

# %%
# Cargando los datos en la variable 'df_reviews'

df_reviews = pd.read_csv('/datasets/imdb_reviews.tsv', sep='\t', dtype={'votes': 'Int64'})

# %%
# Revisando datos aleatorios

df_reviews.sample(5)
# Out:
#           tconst title_type                   primary_title  \
# 23914  tt0323571      movie                    Nemesis Game
# 29673  tt0288808      movie                     Say Nothing
# 12232  tt0388595   tvSeries  Extreme Makeover: Home Edition
# 47187  tt0463392      movie                   Zombie Nation
# 42868  tt0450345      movie                  The Wicker Man
#
#                        original_title  start_year end_year runtime_minutes  \
# 23914                    Nemesis Game        2003       \N              92
# 29673                     Say Nothing        2001       \N              94
# 12232  Extreme Makeover: Home Edition        2003     2020              60
# 47187                   Zombie Nation        2004       \N              81
# 42868                  The Wicker Man        2006       \N             102
#
#        is_adult                   genres  average_rating  votes  \
# 23914         0         Mystery,Thriller             5.5   2008
# ...

# %%
info_data(df_reviews)
# Out:
# 1. Tabla de datos
#           tconst title_type                                 primary_title  \
# 3587   tt0092603      movie                               Babette's Feast
# 21465  tt0411377    tvMovie  Man in the Mirror: The Michael Jackson Story
# 14990  tt0225899      video                                        Granny
# 30248  tt0814314      movie                                  Seven Pounds
# 31385  tt0397103      movie                                         Smile
# 17565  tt0391229      movie             I Want Someone to Eat Cheese With
# 47310  tt0972534   tvSeries                                        iCarly
# 8352   tt0816146      movie                                    Cross Eyed
# 30070  tt0758781      movie                                          Seed
# 39619  tt0365485      movie                                   The Matador
#
#                                      original_title  start_year end_year  \
# ...

# %% [markdown]
# **Hallazgos**
#
# - El conjunto de datos contiene 17 variables(columnas) y 47.311 observaciones(filas).
#
#
# - Existen 2 filas con valores faltantes, en las columnas `average_rating` y `votes`, las cuales seran eliminadas.
#
#
# - La gran mayoria del dataset son variables categoricas de tipo `object`(string).
#
#
# - Las peliculas usadas para el proyecto, se lanzaron desde el año 1894 hasta el año 2010.
#
#
# - El promedio de la columna de la `rating` es de 5.4846, y su mediana es de 4.0, lo que sugiere la prescencia de valores atipicos.
#
#
# - Los datos ya se encuentran particionados en entrenamiento(train) y prueba(test) en la columna `ds_part`.
#
#
# - La calidad de los datos es buena, esto disminuye considerablemente el tiempo del preprocesamiento de los datos.

# %%
# Eliminacion de filas con valores faltantes

df_reviews = df_reviews.dropna()
df_reviews.isna().sum()
# Out:
# tconst             0
# title_type         0
# primary_title      0
# original_title     0
# start_year         0
# end_year           0
# runtime_minutes    0
# is_adult           0
# genres             0
# average_rating     0
# votes              0
# review             0
# rating             0
# sp                 0
# pos                0
# ds_part            0
# idx                0
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor</b> <a class="tocSkip"></a>
#
# Bien hecho con la intro a la data, queda claro qué tipo de tablas utilizaremos en el proyecto
#
# </div>

# %% [markdown]
# ## EDA

# %% [markdown]
# Se realiza analisisi exploratorio de datos con el fin de obtener las tendencias del dataset, por ello, el estudio incluira el número de películas y reseñas a lo largo de los años, la indagacion de la distribucion de las reseñas y la evaluacion del equilibrio de las clases.

# %%
# Comprobar numero de peliculas y reseñas a los largo de los años

fig, axs = plt.subplots(2, 1, figsize = (16, 8))

ax = axs[0]

dft1 = df_reviews[['tconst', 'start_year']].drop_duplicates() \
    ['start_year'].value_counts().sort_index()
dft1 = dft1.reindex(index = np.arange(dft1.index.min(), max(dft1.index.max(), 2011))).fillna(0)
dft1.plot(kind = 'bar', ax = ax)
ax.set_title('Número de películas a lo largo de los años')

ax = axs[1]

dft2 = df_reviews.groupby(['start_year', 'pos'])['pos'].count().unstack()
dft2 = dft2.reindex(index = np.arange(dft2.index.min(), max(dft2.index.max(), 2011))).fillna(0)

dft2.plot(kind = 'bar', stacked = True, label = '#reviews (neg, pos)', ax = ax)

dft2 = df_reviews['start_year'].value_counts().sort_index()
dft2 = dft2.reindex(index = np.arange(dft2.index.min(), max(dft2.index.max(), 2011))).fillna(0)
dft3 = (dft2/dft1).fillna(0)
axt = ax.twinx()
dft3.reset_index(drop = True).rolling(5).mean().plot(color = 'orange', 
                                                   label = 'Reseñas por pelicula (promedio 5 años)', 
                                                   ax = axt)

lines1, labels1 = ax.get_legend_handles_labels()
lines2, labels2 = axt.get_legend_handles_labels()
ax.legend(lines1 + lines2, labels1 + labels2, loc = 'upper left')

ax.set_title('Número de reseñas a lo largo de los años')

fig.tight_layout()

# %% [markdown]
# **Hallazgos**
#
# - El numero de peliculas ha aumentado considerablemente la ultima decada.
#
#
# - Hubo una decadencia en la cantidad de peliculas en la decada de 1960, lo cual se revirtio desde años 70 en adelante.
#
#
# - Al final se observa desde el aaño 2007, una disminucion en produccion de peliculas, aun que es posible que la diferencia se de por el teimpo para recopilar los datos.
#
#
# - La tendencia de las reseñas sigue el patron de numero de peliculas en el periodo analizado.
#
#
# - No existe un aumento significativo, entre las decadas de 1990 y 2000, a pesar del crecimiento en la produccion de peliculas en este periodo.

# %% [markdown]
# Veamos la distribución del número de reseñas por película con el conteo exacto y KDE (solo para saber cómo puede diferir del conteo exacto)

# %%
# Comprobando la distribucion del numero de reseñas por pelicula

fig, axs = plt.subplots(1, 2, figsize=(16, 5))

ax = axs[0]
dft = df_reviews.groupby('tconst')['review'].count() \
    .value_counts() \
    .sort_index()
dft.plot.bar(ax=ax)
ax.set_title('Gráfico de barras de #Reseñas por película')

ax = axs[1]
dft = df_reviews.groupby('tconst')['review'].count()
sns.kdeplot(dft, ax=ax)
ax.set_title('Gráfico KDE de #Reseñas por película')

fig.tight_layout()

# %% [markdown]
# Gran parte de las peliculas tienen un numero limitado de reseñas, menos de 5 reseñas, en contraste, con otra cantidad considerable de peliculas que tienen hasta de 30 reseñas.
#
# Se evalua el desequilibrio de clases en la columna la variable `pos`, que compara reseñas positivas y negativas en los datos. Como se indico anteriormente, `0` son reseñas negativas y `1` son reseñas positivas.

# %%
# Cantidad de valores unicos
value_counts = df_reviews['pos'].value_counts()

# Calculo de la porporcion de valores unicos
value_props = round(df_reviews['pos'].value_counts(normalize=True) * 100, 2).astype('str') + '%'

# Union de los resultados en Dataframe 
df_pos = pd.DataFrame({'total': value_counts, 'percentage': value_props})

# Muestra del Dataframe
df_pos
# Out:
#    total percentage
# 0  23715     50.11%
# 1  23614     49.89%

# %% [markdown]
# El conjunto de datos esta equilibrado en sus clases, aunque hay una pequeña mayor representacion de reseñas negativas.
#
# Ahora, se indagara el equilibrio en la distribucion de las puntuaciones en los conjuntos de entrenamiento(train) y prueba(test), segun la columna `ds_part`.

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

ax = axs[0]
dft = df_reviews.query('ds_part == "train"')['rating'].value_counts().sort_index()
dft = dft.reindex(index=np.arange(min(dft.index.min(), 1), max(dft.index.max(), 11))).fillna(0)
dft.plot.bar(ax=ax)
ax.set_ylim([0, 5000])
ax.set_title('El conjunto de entrenamiento: distribución de puntuaciones')

ax = axs[1]
dft = df_reviews.query('ds_part == "test"')['rating'].value_counts().sort_index()
dft = dft.reindex(index=np.arange(min(dft.index.min(), 1), max(dft.index.max(), 11))).fillna(0)
dft.plot.bar(ax=ax)
ax.set_ylim([0, 5000])
ax.set_title('El conjunto de prueba: distribución de puntuaciones')

fig.tight_layout()

# %% [markdown]
# La distribucion de puntuaciones, es bastante similar entre los conjuntos.

# %% [markdown]
# Distribución de reseñas negativas y positivas a lo largo de los años para dos partes del conjunto de datos

# %%
# Distribucion de las reseñas negativas y positivas por año para ambas partes del set de datos.

fig, axs = plt.subplots(2, 2, figsize=(16, 8), gridspec_kw=dict(width_ratios=(2, 1), height_ratios=(1, 1)))

ax = axs[0][0]

dft = df_reviews.query('ds_part == "train"').groupby(['start_year', 'pos'])['pos'].count().unstack()
dft.index = dft.index.astype('int')
dft = dft.reindex(index=np.arange(dft.index.min(), max(dft.index.max(), 2020))).fillna(0)
dft.plot(kind='bar', stacked=True, ax=ax)
ax.set_title('El conjunto de entrenamiento: número de reseñas de diferentes polaridades por año')

ax = axs[0][1]

dft = df_reviews.query('ds_part == "train"').groupby(['tconst', 'pos'])['pos'].count().unstack()
sns.kdeplot(dft[0], color='blue', label='negative', kernel='epa', ax=ax)
sns.kdeplot(dft[1], color='green', label='positive', kernel='epa', ax=ax)
ax.legend()
ax.set_title('El conjunto de entrenamiento: distribución de diferentes polaridades por película')

ax = axs[1][0]

dft = df_reviews.query('ds_part == "test"').groupby(['start_year', 'pos'])['pos'].count().unstack()
dft.index = dft.index.astype('int')
dft = dft.reindex(index=np.arange(dft.index.min(), max(dft.index.max(), 2020))).fillna(0)
dft.plot(kind='bar', stacked=True, ax=ax)
ax.set_title('El conjunto de prueba: número de reseñas de diferentes polaridades por año')

ax = axs[1][1]

dft = df_reviews.query('ds_part == "test"').groupby(['tconst', 'pos'])['pos'].count().unstack()
sns.kdeplot(dft[0], color='blue', label='negative', kernel='epa', ax=ax)
sns.kdeplot(dft[1], color='green', label='positive', kernel='epa', ax=ax)
ax.legend()
ax.set_title('El conjunto de prueba: distribución de diferentes polaridades por película')

fig.tight_layout()

# %% [markdown]
# La distribucion de las puntuaciones en ambos conjuntos de datos, es semejante, por lo que, para la gran parte de las peliculas, con un pequeño numero de reseñas, predominan las reseñas negativas. Sin embargo, al tener mayor cantidad de reseñas, las puntuaciones positivas se vuelven mas habituales.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor</b> <a class="tocSkip"></a>
#
# Buen trabajo! Esta parte de exploración de la data y las características de las features está muy bien. Las múltiples visualizaciones permiten identificar los años de la data, su frecuencia y características. Nota además que hay una limitación de 30 reseñas por película.
#
# </div>

# %% [markdown]
# ## Procedimiento de evaluación

# %% [markdown]
# Composición de una rutina de evaluación que se pueda usar para todos los modelos en este proyecto

# %%
# Definir funcion de evaluacion

def evaluate_model(model, features_train, target_train, features_test, target_test):
    
    eval_stats = {}
    
    fig, axs = plt.subplots(1, 3, figsize = (20, 6)) 
    
    for type, features, target in (('train', features_train, target_train), ('test', features_test, target_test)):
        
        eval_stats[type] = {}
      
        pred_target = model.predict(features)
        pred_proba = model.predict_proba(features)[:, 1]
        
        # F1
        f1_thresholds = np.arange(0, 1.01, 0.05)
        f1_scores = [metrics.f1_score(target, pred_proba>=threshold) for threshold in f1_thresholds]
        
        # ROC
        fpr, tpr, roc_thresholds = metrics.roc_curve(target, pred_proba)
        roc_auc = metrics.roc_auc_score(target, pred_proba)    
        eval_stats[type]['ROC AUC'] = roc_auc

        # PRC
        precision, recall, pr_thresholds = metrics.precision_recall_curve(target, pred_proba)
        aps = metrics.average_precision_score(target, pred_proba)
        eval_stats[type]['APS'] = aps
        
        if type == 'train':
            color = 'blue'
        else:
            color = 'green'

        # Valor F1
        ax = axs[0]
        max_f1_score_idx = np.argmax(f1_scores)
        ax.plot(f1_thresholds, f1_scores, color=color, label = f'{type}, max = {f1_scores[max_f1_score_idx]:.2f} @ {f1_thresholds[max_f1_score_idx]:.2f}')
        # establecer cruces para algunos umbrales        
        for threshold in (0.2, 0.4, 0.5, 0.6, 0.8):
            closest_value_idx = np.argmin(np.abs(f1_thresholds-threshold))
            marker_color = 'orange' if threshold != 0.5 else 'red'
            ax.plot(f1_thresholds[closest_value_idx], f1_scores[closest_value_idx], color=marker_color, marker='X', markersize=7)
        ax.set_xlim([-0.02, 1.02])    
        ax.set_ylim([-0.02, 1.02])
        ax.set_xlabel('threshold')   
        ax.set_ylabel('F1')
        ax.legend(loc = 'lower center')
        ax.set_title(f'Valor F1') 

        # ROC
        ax = axs[1]    
        ax.plot(fpr, tpr, color = color, label = f'{type}, ROC AUC = {roc_auc:.2f}')
        # establecer cruces para algunos umbrales        
        for threshold in (0.2, 0.4, 0.5, 0.6, 0.8):
            closest_value_idx = np.argmin(np.abs(roc_thresholds-threshold))
            marker_color = 'orange' if threshold != 0.5 else 'red'            
            ax.plot(fpr[closest_value_idx], tpr[closest_value_idx], color = marker_color, marker = 'X', markersize = 7)
        ax.plot([0, 1], [0, 1], color = 'grey', linestyle = '--')
        ax.set_xlim([-0.02, 1.02])    
        ax.set_ylim([-0.02, 1.02])
        ax.set_xlabel('FPR')
        ax.set_ylabel('TPR')
        ax.legend(loc = 'lower center')        
        ax.set_title(f'Curva ROC')
        
        # PRC
        ax = axs[2]
        ax.plot(recall, precision, color = color, label = f'{type}, AP={aps:.2f}')
        # establecer cruces para algunos umbrales        
        for threshold in (0.2, 0.4, 0.5, 0.6, 0.8):
            closest_value_idx = np.argmin(np.abs(pr_thresholds-threshold))
            marker_color = 'orange' if threshold != 0.5 else 'red'
            ax.plot(recall[closest_value_idx], precision[closest_value_idx],
                    color = marker_color, marker = 'X', markersize = 7)
        ax.set_xlim([-0.02, 1.02])    
        ax.set_ylim([-0.02, 1.02])
        ax.set_xlabel('recall')
        ax.set_ylabel('precision')
        ax.legend(loc = 'lower center')
        ax.set_title(f'PRC')        

        eval_stats[type]['Exactitud'] = metrics.accuracy_score(target, pred_target)
        eval_stats[type]['F1'] = metrics.f1_score(target, pred_target)
    
    df_eval_stats = pd.DataFrame(eval_stats)
    df_eval_stats = df_eval_stats.round(2)
    df_eval_stats = df_eval_stats.reindex(index = ('Exactitud', 'F1', 'APS', 'ROC AUC'))
    
    return df_eval_stats

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor</b> <a class="tocSkip"></a>
#
# Bien hecho, muy bien con la función, está completa y adecuada para mostrar los resultados de cada evaluación
#
#
# </div>

# %% [markdown]
# ## Normalización

# %% [markdown]
# Suponemos que todos los modelos a continuación aceptan textos en minúsculas y sin dígitos, signos de puntuación, etc.

# %%
# Convertir a letra minuscula todas las reseñas
df_reviews['review_norm'] = df_reviews['review'].str.lower()

# Eliminacion de numeros, signos de puntuacion y otros caracteres que no sean letras ni espacios
df_reviews['review_norm'] = df_reviews['review_norm'].apply(lambda x: re.sub(r'[^a-z\s]', '', x))

# %%
# Comprobar y comparar resultados

df_reviews [['review', 'review_norm']]
# Out:
#                                                   review  \
# 0      The pakage implies that Warren Beatty and Gold...
# 1      How the hell did they get this made?! Presenti...
# 2      There is no real story the film seems more lik...
# 3      Um .... a serious film about troubled teens in...
# 4      I'm totally agree with GarryJohal from Singapo...
# ...                                                  ...
# 47326  This is another of my favorite Columbos. It sp...
# 47327  Talk about being boring! I got this expecting ...
# 47328  I never thought I'd say this about a biopic, b...
# 47329  Spirit and Chaos is an artistic biopic of Miya...
# 47330  I'll make this brief. This was a joy to watch....
#
#                                              review_norm
# 0      the pakage implies that warren beatty and gold...
# 1      how the hell did they get this made presenting...
# 2      there is no real story the film seems more lik...
# ...

# %% [markdown]
# El procesamiento de las reseñas se logro correctamente.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor</b> <a class="tocSkip"></a>
#
# Correcto, haces muy bien al comparar ambas columnas.
#
# </div>

# %% [markdown]
# ## División entrenamiento / prueba

# %% [markdown]
# Por fortuna, todo el conjunto de datos ya está dividido en partes de entrenamiento/prueba; 'ds_part' es el indicador correspondiente.
#
# Por lo que, se particionara el conjunto de datos en las dos clases de la columna `ds_part`, que son 'train'(entrenamiento) y 'test'(prueba).

# %%
# Crear dos nuevos datasets para entrenamiento(train) y prueba(test)

features_train = df_reviews.query('ds_part == "train"').copy()
features_test = df_reviews.query('ds_part == "test"').copy()

target_train = features_train['pos']
target_test = features_test['pos']

print(features_train.shape)
print(features_test.shape)
# Out:
# (23796, 18)
# (23533, 18)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor</b> <a class="tocSkip"></a>
#
# Bien, correcto
#
# </div>

# %% [markdown]
# ## Trabajar con modelos
#
# En este punto, se entrenana los modelos de machine learning para relizar el analisis de sentimientos, en el conjunto de entrenamiento.
#
# Para esto, se aplicaran varios modelos, con el fin de comparar su precision y determinar cual es el de mejor desempeño.
#
# Por ultimo, para tener una referencia, inicialmente se utilizara un modelo constante, donde su prediccion genera un unico valor, precisamente 1, por lo que un modelo mas avanazado deberia superar el rendimiento de este modelo base.

# %% [markdown]
# ### Modelo 0 - Constante

# %%
# Implementar modelo DummyClassifier con una 'constante'

dc = DummyClassifier(strategy='constant', constant=1).fit(features_train, target_train)

dc_score = evaluate_model(dc, features_train, target_train, features_test, target_test)
dc_score
# Out:
#            train  test
# Exactitud   0.50  0.50
# F1          0.67  0.67
# APS         0.50  0.50
# ROC AUC     0.50  0.50

# %% [markdown]
# ### Modelo 1 - NLTK, TF-IDF y Logistic Regression

# %% [markdown]
# Se prueban los modelos utilizando el metodo TF-IDF(Frecuancia de termino-frecuencia inversa de documento), que es la tecnica habitual en el procesamiento de del lenguaje natural, la cual evalua la importancia de las palabras en un documento. Este metodo calcula la frecuencia de una palabra en el documento(TF) y la frecuencia con la que la palabra aparece en los documentos del conjunto de datos(IDF).
#
# Proximamente, se va utilizar las bibliotecas NLTK(Natural Language Tollkit) y SpaCy para el procesamiento del lenguaje natural(NLP en sus sigla en ingles), para las cuales se implementaran diferentes metodos de TF-IDF.
#
# En este caso se utilza NLTK, para el modelo de Regresion Logistica.

# %% [markdown]
# #### Implementar metodo TF-IDF y preprocesamiento NLTK

# %%
# Preprocesamiento de texto con NLTK

nltk.download('punkt')
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/jovyan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Tokenizar y lematizar la columna 'review_norm' con bucle for para el conjunto de entrenamiento

features_train_nltk = []
for text in features_train['review_norm']:
    tokens = word_tokenize(text)
    lemmas = [lemmatizer.lemmatize(token) for token in tokens]
    join = " ".join(lemmas)
    features_train_nltk.append(join)

# %%
# Tokenizar y lematizar la columna 'review_norm' con bucle for para el conjunto de prueba

features_test_nltk = []
for text in features_test['review_norm']:
    tokens = word_tokenize(text)
    lemmas = [lemmatizer.lemmatize(token) for token in tokens]
    join = " ".join(lemmas)
    features_test_nltk.append(join)

# %%
# Aplicar metodo TF-IDF y eliminar palabras vacias

stop_words = set(nltk_stopwords.words('english'))
tf_idf = TfidfVectorizer(stop_words = stop_words)

# %% [markdown]
# #### Logistic Regression - NLTK

# %%
# Crear nuevas caracteristicas e implementar TF-IDF

features_train_logr_nltk = tf_idf.fit_transform(features_train_nltk)
features_test_logr_nltk = tf_idf.transform(features_test_nltk)

# %%
# Crear modelo Logistic Regression sin ajuste de hiperparametros

logr_nltk = LogisticRegression().fit(features_train_logr_nltk, target_train)

# %%
# Evaluar modelo

logr_nltk_score = evaluate_model(logr_nltk, features_train_logr_nltk, target_train, features_test_logr_nltk, target_test)
logr_nltk_score
# Out:
#            train  test
# Exactitud   0.94  0.88
# F1          0.94  0.88
# APS         0.98  0.95
# ROC AUC     0.98  0.95

# %% [markdown]
# Modelo con buena puntuacion, mucho mejor que el modelo referencial.

# %% [markdown]
# #### Prueba modelo Logistic Regression - NLTK con nuevo conjunto de prueba

# %% [markdown]
# Se prueba el modelo desarrollado en un nuevo set de datos que tiene nuevas reseñas. Muestra de 10 reseñas aleatorias, divididas de forma justa entre positivas y negativas, donde el modelo proporcionara valoraciones de probabilidad para las reseñas.
#
# La puntuacion cercana a 1, indica que la reseña es positiva, al contrario si la puntuacion es cercana a 0, señala que la reseña es negativa.
#
# Este enfoque se utilizara en futuros modelos.

# %%
# Crear nuevo dataframe con 10 lineas de reseñas de peliculas
# Reseñas positivas y negativas alternadas, la primera es negativa

my_reviews = pd.DataFrame([
    "This movie was an absolute waste of time. I wouldn't recommend it to anyone.",
    "I was thoroughly impressed with this film. The storyline was engaging and the acting was superb.",
    "I found this movie to be incredibly boring. It just didn't hold my attention.",
    "The special effects in this movie were out of this world. Definitely worth watching.",
    "I was disappointed by this film. It didn't live up to the hype.",
    "This movie was a masterpiece. I was blown away by the stunning visuals and emotional storyline.",
    "I thought the acting in this movie was terrible. It was hard to watch.",
    "I couldn't take my eyes off the screen. This movie had me on the edge of my seat from start to finish.",
    "The dialogue in this movie was so cheesy. I couldn't take it seriously.",
    "I loved this film. It had all the right elements to make a great movie.",
], columns=['review'])

my_reviews['review_norm'] = my_reviews['review'].str.lower().apply(lambda x: re.sub(r'[^a-z\s]', '', x))

my_reviews
# Out:
#                                               review  \
# 0  This movie was an absolute waste of time. I wo...
# 1  I was thoroughly impressed with this film. The...
# 2  I found this movie to be incredibly boring. It...
# 3  The special effects in this movie were out of ...
# 4  I was disappointed by this film. It didn't liv...
# 5  This movie was a masterpiece. I was blown away...
# 6  I thought the acting in this movie was terribl...
# 7  I couldn't take my eyes off the screen. This m...
# 8  The dialogue in this movie was so cheesy. I co...
# 9  I loved this film. It had all the right elemen...
#
#                                          review_norm
# 0  this movie was an absolute waste of time i wou...
# 1  i was thoroughly impressed with this film the ...
# 2  i found this movie to be incredibly boring it ...
# 3  the special effects in this movie were out of ...
# 4  i was disappointed by this film it didnt live ...
# 5  this movie was a masterpiece i was blown away ...
# ...

# %%
# Calculo de la puntuacion de probabilidad basada en el modelo

texts = my_reviews['review_norm']

my_reviews_pred_prob = logr_nltk.predict_proba(tf_idf.transform(texts))[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.08:  this movie was an absolute waste of time i wouldnt recommend it to anyone
# 0.82:  i was thoroughly impressed with this film the storyline was engaging and the acting was superb
# 0.08:  i found this movie to be incredibly boring it just didnt hold my attention
# 0.96:  the special effects in this movie were out of this world definitely worth watching
# 0.15:  i was disappointed by this film it didnt live up to the hype
# 0.85:  this movie was a masterpiece i was blown away by the stunning visuals and emotional storyline
# 0.07:  i thought the acting in this movie was terrible it was hard to watch
# 0.49:  i couldnt take my eyes off the screen this movie had me on the edge of my seat from start to finish
# 0.09:  the dialogue in this movie was so cheesy i couldnt take it seriously
# 1.00:  i loved this film it had all the right elements to make a great movie

# %% [markdown]
# El modelo muestra una diferencia clara entre las probabilidades de reseñas positivas y negativas, como se aprecia en el primer registro, que es una reseña negativa, la probabilidad es cercana a 0, y el segundo registro es una reseña positiva, ya que la probabilidad esta muy proxima a 1.

# %% [markdown]
# ### Modelo 2 - spaCy, TF-IDF y Logistic Regression

# %% [markdown]
# Con la biblioteca SpaCy para el procesamiento de lenguaje natural (NLP), se aplicaran los mismos pasos que en el primer modelo.

# %% [markdown]
# #### Implementar metodo TF-IDF y preprocesamiento SpaCy

# %%
# Preprocesamiento de texto con SpaCy, convertir modelos en ingles en variables NLP

nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# Definir funcion para lematizar y eliminar palabras vacias 

def text_preprocessing(text):
    doc = nlp(text)
    tokens = [token.lemma_ for token in doc if not token.is_stop]
        
    return ' '.join(tokens)

# %%
# Crear nuevos conjuntos de entrenamiento y prueba con la funcion anterior (text_preprocessing)

features_train_spacy = features_train['review_norm'].apply(lambda x: text_preprocessing(x))
features_test_spacy = features_test['review_norm'].apply(lambda x: text_preprocessing(x))

# %%
# Implementar metodo TF-IDF

tf_idf_2 = TfidfVectorizer()
features_train_logr_spacy = tf_idf_2.fit_transform(features_train_spacy)
features_test_logr_spacy = tf_idf_2.transform(features_test_spacy)

# %% [markdown]
# #### Logistic Regression - SpaCy

# %%
# Crear modelo Logistic Regression sin ajuste de hiperparametros

logr_spacy = LogisticRegression().fit(features_train_logr_spacy, target_train)

# %%
# Evaluar modelo 

logr_spacy_score = evaluate_model(logr_spacy, features_train_logr_spacy, target_train, features_test_logr_spacy, target_test)
logr_spacy_score
# Out:
#            train  test
# Exactitud   0.93  0.87
# F1          0.93  0.87
# APS         0.98  0.94
# ROC AUC     0.98  0.95

# %% [markdown]
# La puntuacion no es significativamente superior, con respecto al modelo anterior.

# %% [markdown]
# #### Prueba modelo Logistic Regression - SpaCy con nuevo conjunto de prueba

# %%
# Calculo de la puntuacion de probabilidad basada en el modelo

texts = my_reviews['review_norm']

my_reviews_pred_prob = logr_spacy.predict_proba(tf_idf_2.transform(texts.apply(lambda x: text_preprocessing(x))))[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.05:  this movie was an absolute waste of time i wouldnt recommend it to anyone
# 0.78:  i was thoroughly impressed with this film the storyline was engaging and the acting was superb
# 0.10:  i found this movie to be incredibly boring it just didnt hold my attention
# 0.96:  the special effects in this movie were out of this world definitely worth watching
# 0.22:  i was disappointed by this film it didnt live up to the hype
# 0.85:  this movie was a masterpiece i was blown away by the stunning visuals and emotional storyline
# 0.03:  i thought the acting in this movie was terrible it was hard to watch
# 0.68:  i couldnt take my eyes off the screen this movie had me on the edge of my seat from start to finish
# 0.08:  the dialogue in this movie was so cheesy i couldnt take it seriously
# 1.00:  i loved this film it had all the right elements to make a great movie

# %% [markdown]
# Modelo de buen desempeño de predicciones, diferencias claras en las probabilidades.
#
# Como el modelo anterior, predice con mucha perfecta precision la probilidad positiva en la linea 10, la cual contiene la palabra "love".

# %% [markdown]
# ### Modelo 4 - NLTK, TF-IDF y LGBM Classifier

# %% [markdown]
# Se procede a probar el modelo de potenciacion de gradiente, LGBM Classifier, nuevamente se utilizara el metodo TF-IDF para NLP con la libreria NLTK

# %% [markdown]
# #### Implementar metodo TF-IDF y preprocesamiento NLTK

# %%
# Crear nuevos conjuntos de entrenamiento y prueba, aplicar metodo TF-IDF y eliminar palabras vacias

features_train_lgbm_nltk = tf_idf.fit_transform(features_train_nltk)
features_test_lgbm_nltk = tf_idf.transform(features_test_nltk)

# %% [markdown]
# #### LightGBM Calssifier - NLTK

# %%
# Crear modelo LightGBM Classifier sin ajuste de hiperparametros

lgbm_nltk = LGBMClassifier().fit(features_train_lgbm_nltk, target_train)

# %%
# Evaluar modelo

lgbm_nltk_score = evaluate_model(lgbm_nltk, features_train_lgbm_nltk, target_train, features_test_lgbm_nltk, target_test)
lgbm_nltk_score
# Out:
#            train  test
# Exactitud   0.91  0.86
# F1          0.92  0.86
# APS         0.97  0.93
# ROC AUC     0.97  0.94

# %% [markdown]
# El modelo `LightGBM Classifier`, con preprocesamiento `NLTK`, en terminos de puntuacion, su desempeño no supera a la Regresion Logistica, para ambos casos.

# %% [markdown]
# #### Prueba modelo LightGBM Classifier - NLTK con nuevo conjunto de prueba

# %%
# Calculo de la puntuacion de probabilidad basada en el modelo

my_reviews_pred_prob = lgbm_nltk.predict_proba(tf_idf.transform(texts))[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.12:  this movie was an absolute waste of time i wouldnt recommend it to anyone
# 0.86:  i was thoroughly impressed with this film the storyline was engaging and the acting was superb
# 0.17:  i found this movie to be incredibly boring it just didnt hold my attention
# 0.87:  the special effects in this movie were out of this world definitely worth watching
# 0.54:  i was disappointed by this film it didnt live up to the hype
# 0.78:  this movie was a masterpiece i was blown away by the stunning visuals and emotional storyline
# 0.17:  i thought the acting in this movie was terrible it was hard to watch
# 0.56:  i couldnt take my eyes off the screen this movie had me on the edge of my seat from start to finish
# 0.46:  the dialogue in this movie was so cheesy i couldnt take it seriously
# 0.92:  i loved this film it had all the right elements to make a great movie

# %% [markdown]
# Tiene buena capacidad para discernir entre reseñas positivas y negativas, pero en su forma no es tan preciso como los modelos anteriores.
#
# Como se aprecia en la linea 5, el modelo valora erroneamente una reseña negativa como positiva con una probabilidad del 54%, igualmente en la fila 9. Por lo que si el umbral se define en el 50%, aunque la diferencia es relativamente pequeña, la prediccion de igual forma es incorrecta.

# %% [markdown]
# ### Modelo 4 - spaCy, TF-IDF y LGBM Classifier

# %% [markdown]
# Nuevamente se aplicara el modelo LightGBM Classifier, con el metodo TF-IDF pero el NLP de SpaCy.

# %% [markdown]
# #### Implementar metodo TF-IDF y preprocesamiento SpaCy

# %%
# Crear nuevos conjuntos de datos e implementar metodo TF-IDF

features_train_lgbm_spacy = tf_idf_2.fit_transform(features_train_spacy)
features_test_lgbm_spacy = tf_idf_2.transform(features_test_spacy)

# %% [markdown]
# #### LightGBM Classifier - SpaCy

# %%
# Crear modelo LightGBM Classifier sin ajuste de hiperparametros

lgbm_spacy = LGBMClassifier().fit(features_train_lgbm_spacy, target_train)

# %%
# Evaluar modelo

lgbm_spacy_score = evaluate_model(lgbm_spacy, features_train_lgbm_spacy, target_train, features_test_lgbm_spacy, target_test)
lgbm_spacy_score
# Out:
#            train  test
# Exactitud   0.91  0.85
# F1          0.91  0.85
# APS         0.97  0.93
# ROC AUC     0.97  0.93

# %% [markdown]
# La puntuacion disminuyo.

# %% [markdown]
# #### Prueba modelo LightGBM Classifier - SpaCy con nuevo conjunto de prueba

# %%
# Calculo de la puntuacion de probabilidad basada en el modelo

texts = my_reviews['review_norm']

my_reviews_pred_prob = lgbm_spacy.predict_proba(tf_idf_2.transform(texts.apply(lambda x: text_preprocessing(x))))[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.09:  this movie was an absolute waste of time i wouldnt recommend it to anyone
# 0.83:  i was thoroughly impressed with this film the storyline was engaging and the acting was superb
# 0.14:  i found this movie to be incredibly boring it just didnt hold my attention
# 0.86:  the special effects in this movie were out of this world definitely worth watching
# 0.38:  i was disappointed by this film it didnt live up to the hype
# 0.79:  this movie was a masterpiece i was blown away by the stunning visuals and emotional storyline
# 0.15:  i thought the acting in this movie was terrible it was hard to watch
# 0.46:  i couldnt take my eyes off the screen this movie had me on the edge of my seat from start to finish
# 0.37:  the dialogue in this movie was so cheesy i couldnt take it seriously
# 0.94:  i loved this film it had all the right elements to make a great movie

# %% [markdown]
# El modelo funciona bien, en terminos de prediccion, pero tiene un error en la octava linea.

# %% [markdown]
# ### Modelo 5 - NLTK, TF-IDF y XGBoost Classifier

# %% [markdown]
# Se implementa la potenciacion de gradiente, con XGBoost Classifier.

# %% [markdown]
# #### Implementar metodo TF-IDF y preprocesamiento NLTK

# %%
# Crear nuevos conjuntos de datos, aplicar metodo TF-IDF y eliminar palabras vacias

features_train_xgbc_nltk = tf_idf.fit_transform(features_train_nltk)
features_test_xgbc_nltk = tf_idf.transform(features_test_nltk)

# %% [markdown]
# #### XGBoost Classifier - NLTK

# %%
# Crear modelo XGBGoost Classifier sin ajuste de hiperparametros

xgbc_nltk = XGBClassifier(objective='binary:logistic', eval_metric='logloss').fit(features_train_xgbc_nltk, target_train)

# %%
# Evaluar modelo

xgbc_nltk_score = evaluate_model(xgbc_nltk, features_train_xgbc_nltk, target_train, features_test_xgbc_nltk, target_test)
xgbc_nltk_score
# Out:
#            train  test
# Exactitud   0.95  0.85
# F1          0.95  0.85
# APS         0.99  0.93
# ROC AUC     0.99  0.93

# %% [markdown]
# Se obtiene mejor puntuacion que en el modelo 1, en el conjunto de entrenamiento, pero en el conjunto de prueba sigue la puntuacion siendo menor.

# %% [markdown]
# #### Prueba modelo XGBoost Classifier - NLTK con nuevo conjunto de prueba

# %%
# Calculo de la puntuacion de probabilidad basada en el modelo

my_reviews_pred_prob = xgbc_nltk.predict_proba(tf_idf.transform(texts))[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.12:  this movie was an absolute waste of time i wouldnt recommend it to anyone
# 0.79:  i was thoroughly impressed with this film the storyline was engaging and the acting was superb
# 0.27:  i found this movie to be incredibly boring it just didnt hold my attention
# 0.76:  the special effects in this movie were out of this world definitely worth watching
# 0.58:  i was disappointed by this film it didnt live up to the hype
# 0.66:  this movie was a masterpiece i was blown away by the stunning visuals and emotional storyline
# 0.21:  i thought the acting in this movie was terrible it was hard to watch
# 0.51:  i couldnt take my eyes off the screen this movie had me on the edge of my seat from start to finish
# 0.51:  the dialogue in this movie was so cheesy i couldnt take it seriously
# 0.90:  i loved this film it had all the right elements to make a great movie

# %% [markdown]
# Modelo con desempaño deficiente en las predicciones, ya que en las lineas 5 y 9, los errores son evidentes. Ademas el descernimiento no es claro, ya que varias probabilidades se encuentran cercanas al valor medio, lo que indica que no puede predecir con certeza las reseñas.

# %% [markdown]
# ### Modelo 6 - SpaCy, TF-IDF y XGBoost Classifier

# %% [markdown]
# #### Implementar metodo TF-IDF y preprocesamiento SpaCy

# %%
# Crear nuevos conjuntos de datos y aplicar metodo TF-IDF

features_train_xgbc_spacy = tf_idf_2.fit_transform(features_train_spacy)
features_test_xgbc_spacy = tf_idf_2.transform(features_test_spacy)

# %% [markdown]
# #### XGBoost Classifier - SpaCy

# %%
# Crear modelo XGBoost Classifier sin ajuste de hiperparametros

xgbc_spacy = XGBClassifier(objective='binary:logistic', eval_metric='logloss').fit(features_train_xgbc_spacy, target_train)

# %%
# Evaluar modelo

xgbc_spacy_score = evaluate_model(xgbc_spacy, features_train_xgbc_spacy, target_train, features_test_xgbc_spacy, target_test)
xgbc_spacy_score
# Out:
#            train  test
# Exactitud   0.94  0.84
# F1          0.94  0.85
# APS         0.99  0.92
# ROC AUC     0.99  0.92

# %% [markdown]
# El modelo 5 tiene mejores resultados.

# %% [markdown]
# #### Prueba modelo XGBoost Classifier - SpaCy con nuevo conjunto de prueba

# %%
# Calculo de la puntuacion de probabilidad basada en el modelo

texts = my_reviews['review_norm']

my_reviews_pred_prob = xgbc_spacy.predict_proba(tf_idf_2.transform(texts.apply(lambda x: text_preprocessing(x))))[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.10:  this movie was an absolute waste of time i wouldnt recommend it to anyone
# 0.81:  i was thoroughly impressed with this film the storyline was engaging and the acting was superb
# 0.17:  i found this movie to be incredibly boring it just didnt hold my attention
# 0.85:  the special effects in this movie were out of this world definitely worth watching
# 0.50:  i was disappointed by this film it didnt live up to the hype
# 0.71:  this movie was a masterpiece i was blown away by the stunning visuals and emotional storyline
# 0.21:  i thought the acting in this movie was terrible it was hard to watch
# 0.44:  i couldnt take my eyes off the screen this movie had me on the edge of my seat from start to finish
# 0.47:  the dialogue in this movie was so cheesy i couldnt take it seriously
# 0.92:  i loved this film it had all the right elements to make a great movie

# %% [markdown]
# Sigue deficiente en la precision de las predicciones, no logra discernir correctamente la octava linea.

# %% [markdown]
# ### Modelo 7 - NLTK, TF-IDF y CatBoost Classifier

# %% [markdown]
# Se implementa la potenciacion de gradiente, con CatBoost Classifier.

# %% [markdown]
# #### Implementar metodo TF-IDF y preprocesamiento NLTK

# %%
# Crear nuevos conjuntos de datos, aplicar metodo TF-IDF y eliminar palabras vacias

features_train_cbc_nltk = tf_idf.fit_transform(features_train_nltk)
features_test_cbc_nltk = tf_idf.transform(features_test_nltk)

# %% [markdown]
# #### CatBoost Classifier - NLTK

# %%
# Crear modelo CatBoost Classifier sin ajuste de hiperparametros

cbc_nltk = CatBoostClassifier(verbose=500).fit(features_train_cbc_nltk, target_train)
# Out:
# Learning rate set to 0.039875
# 0:	learn: 0.6823932	total: 2.05s	remaining: 34m 5s
# 500:	learn: 0.3214737	total: 10m 35s	remaining: 10m 33s
# 999:	learn: 0.2496172	total: 19m 53s	remaining: 0us

# %%
# Evaluar modelo

cbc_nltk_score = evaluate_model(cbc_nltk, features_train_cbc_nltk, target_train, features_test_cbc_nltk, target_test)
cbc_nltk_score
# Out:
#            train  test
# Exactitud   0.92  0.87
# F1          0.93  0.87
# APS         0.98  0.94
# ROC AUC     0.98  0.94

# %% [markdown]
# El modelo 1, sigue siendo el de mejor desempeño.

# %% [markdown]
# #### Prueba modelo CatBoost Classifier - NLTK con nuevo conjunto de prueba

# %%
# Calculo de la puntuacion de probabilidad basada en el modelo

my_reviews_pred_prob = cbc_nltk.predict_proba(tf_idf.transform(texts))[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.23:  this movie was an absolute waste of time i wouldnt recommend it to anyone
# 0.75:  i was thoroughly impressed with this film the storyline was engaging and the acting was superb
# 0.30:  i found this movie to be incredibly boring it just didnt hold my attention
# 0.78:  the special effects in this movie were out of this world definitely worth watching
# 0.53:  i was disappointed by this film it didnt live up to the hype
# 0.70:  this movie was a masterpiece i was blown away by the stunning visuals and emotional storyline
# 0.31:  i thought the acting in this movie was terrible it was hard to watch
# 0.55:  i couldnt take my eyes off the screen this movie had me on the edge of my seat from start to finish
# 0.48:  the dialogue in this movie was so cheesy i couldnt take it seriously
# 0.88:  i loved this film it had all the right elements to make a great movie

# %% [markdown]
# El modelo tambien presenta errores al discernir las reseñas, tiene errores en las lineas 5 y 9.

# %% [markdown]
# ### Modelo 8 - SpaCy, TF-IDF y CatBoost Classifier

# %% [markdown]
# #### Implementar metodo TF-IDF y preprocesamiento SpaCy

# %%
# Crear nuevos conjutnos de datos y aplicar metodo TF-IDF

features_train_cbc_spacy = tf_idf_2.fit_transform(features_train_spacy)
features_test_cbc_spacy = tf_idf_2.transform(features_test_spacy)

# %% [markdown]
# #### CatBoost Classifier - SpaCy

# %%
# Crear modelo CatBoost Classifier

cbc_spacy = CatBoostClassifier(verbose=500).fit(features_train_cbc_spacy, target_train)
# Out:
# Learning rate set to 0.039875
# 0:	learn: 0.6811987	total: 1.33s	remaining: 22m 11s
# 500:	learn: 0.3285105	total: 8m 20s	remaining: 8m 18s
# 999:	learn: 0.2590396	total: 16m 34s	remaining: 0us

# %%
# Evaluar modelo

cbc_spacy_score = evaluate_model(cbc_spacy, features_train_cbc_spacy, target_train, features_test_cbc_spacy, target_test)
cbc_spacy_score
# Out:
#            train  test
# Exactitud   0.92  0.86
# F1          0.92  0.86
# APS         0.98  0.93
# ROC AUC     0.98  0.94

# %% [markdown]
# #### Prueba modelo CatBoost Classifier - SpaCy con nuevo conjunto de prueba

# %%
# Calculo de la puntuacion de probabilidad basada en el modelo

texts = my_reviews['review_norm']

my_reviews_pred_prob = cbc_spacy.predict_proba(tf_idf_2.transform(texts.apply(lambda x: text_preprocessing(x))))[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.18:  this movie was an absolute waste of time i wouldnt recommend it to anyone
# 0.74:  i was thoroughly impressed with this film the storyline was engaging and the acting was superb
# 0.24:  i found this movie to be incredibly boring it just didnt hold my attention
# 0.77:  the special effects in this movie were out of this world definitely worth watching
# 0.46:  i was disappointed by this film it didnt live up to the hype
# 0.67:  this movie was a masterpiece i was blown away by the stunning visuals and emotional storyline
# 0.29:  i thought the acting in this movie was terrible it was hard to watch
# 0.51:  i couldnt take my eyes off the screen this movie had me on the edge of my seat from start to finish
# 0.43:  the dialogue in this movie was so cheesy i couldnt take it seriously
# 0.92:  i loved this film it had all the right elements to make a great movie

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor</b> <a class="tocSkip"></a>
#
# Excelente trabajo con los modelos, probaste una gran variedad de preprocesos y modelos.
#
# Muy bien también con los testeos, nos da una indicación de qué realzan más para distinguir las calificaciones
#
# </div>

# %% [markdown]
# ## Conclusiones

# %% [markdown]
# Este proyecto evalua 8 modelos diferentes, los cuales, todos sobrepasaron la puntuacion F1 minima establecida de 0.85, para esta tarea. Sin embargo, existen diferencias de caildad entre los modelos.
#
# El `Modelo 1`, entrenado con `Regresion Logistica (Logistic Regression)`, aplicado con metodo `TF-IDF` y la libreria `NLTK` para NLP, obtiene el mejor desempeño, que alcanza una puntuacion F1 de 0.88, en el cojunto de prueba.

# %%
# Unificar variables de puntuaciones en un solo dataframe

all_score = pd.concat([dc_score, logr_nltk_score, logr_spacy_score, lgbm_nltk_score, lgbm_spacy_score, 
                       xgbc_nltk_score, xgbc_spacy_score, cbc_nltk_score, cbc_spacy_score], axis=1)

# Cambiar indice a nombres de columnas y cambiar columnas a filas

all_score = all_score.T.rename_axis('Modelo').set_index(
    pd.Index(['Modelo_0_Entrenamiento', 'Modelo_0_Prueba', 'Modelo_1_Entrenamiento', 'Modelo_1_Prueba',
              'Modelo_2_Entrenamiento', 'Modelo_2_Prueba', 'Modelo_3_Entrenamiento', 'Modelo_3_Prueba', 
              'Modelo_4_Entrenamiento', 'Modelo_4_Prueba', 'Modelo_5_Entrenamiento', 'Modelo_5_Prueba',
              'Modelo_6_Entrenamiento', 'Modelo_6_Prueba', 'Modelo_7_Entrenamiento', 'Modelo_7_Prueba',
              'Modelo_8_Entrenamiento', 'Modelo_8_Prueba']))
model_name = ['Constante', '^', 'NLTK Logistic Regression', '^', 'SpaCy Logistic Regression', '^', 'NLTK LightGBM', '^',
              'SpaCy LightGBM', '^', 'NLTK XGBoost', '^', 'SpaCy XGBoost', '^', 'NLTK Catboost', '^', 'SpaCy Catboost', '^']
all_score.insert(0, 'Model', model_name)
all_score
# Out:
#                                             Model  Exactitud    F1   APS  \
# Modelo_0_Entrenamiento                  Constante       0.50  0.67  0.50
# Modelo_0_Prueba                                 ^       0.50  0.67  0.50
# Modelo_1_Entrenamiento   NLTK Logistic Regression       0.94  0.94  0.98
# Modelo_1_Prueba                                 ^       0.88  0.88  0.95
# Modelo_2_Entrenamiento  SpaCy Logistic Regression       0.93  0.93  0.98
# Modelo_2_Prueba                                 ^       0.87  0.87  0.94
# Modelo_3_Entrenamiento              NLTK LightGBM       0.91  0.92  0.97
# Modelo_3_Prueba                                 ^       0.86  0.86  0.93
# Modelo_4_Entrenamiento             SpaCy LightGBM       0.91  0.91  0.97
# Modelo_4_Prueba                                 ^       0.85  0.85  0.93
# Modelo_5_Entrenamiento               NLTK XGBoost       0.95  0.95  0.99
# Modelo_5_Prueba                                 ^       0.85  0.85  0.93
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor</b> <a class="tocSkip"></a>
#
# Muy bien con el cuadro resumen!
#
# </div>

# %% [markdown]
# # Lista de comprobación

# %% [markdown]
# - [x]  Abriste el notebook
# - [ ]  Cargaste y preprocesaste los datos de texto para su vectorización
# - [ ]  Transformaste los datos de texto en vectores
# - [ ]  Entrenaste y probaste los modelos
# - [ ]  Se alcanzó el umbral de la métrica
# - [ ]  Colocaste todas las celdas de código en el orden de su ejecución
# - [ ]  Puedes ejecutar sin errores todas las celdas de código
# - [ ]  Hay conclusiones
