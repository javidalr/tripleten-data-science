# %% [markdown]
# <center><h1><u>ICE Store  -  Modelo Campaña 2017</u></h1></center>

# %% [markdown]
# Hola Javier!
#
# Soy **Patricio Requena** 👋. Es un placer ser el revisor de tu proyecto el día de hoy!
#
# Revisaré tu proyecto detenidamente con el objetivo de ayudarte a mejorar y perfeccionar tus habilidades. Durante mi revisión, identificaré áreas donde puedas hacer mejoras en tu código, señalando específicamente qué y cómo podrías ajustar para optimizar el rendimiento y la claridad de tu proyecto. Además, es importante para mí destacar los aspectos que has manejado excepcionalmente bien. Reconocer tus fortalezas te ayudará a entender qué técnicas y métodos están funcionando a tu favor y cómo puedes aplicarlos en futuras tareas.
#
# _**Recuerda que al final de este notebook encontrarás un comentario general de mi parte**_, empecemos!
#
# Encontrarás mis comentarios dentro de cajas verdes, amarillas o rojas, ⚠️ **por favor, no muevas, modifiques o borres mis comentarios** ⚠️:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si todo está perfecto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma:
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class=“tocSkip”></a>
# </div>

# %% [markdown]
# ## **Información General**

# %%
# Importando librerias del proyecto

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats as st

# %%
# Cargando datos del proyecto a traves de libreria pandas

games = pd.read_csv('/datasets/games.csv')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Buen trabajo con la carga de datos y la importación de las librerías necesarias!
# </div>

# %%
# Vista previa de los datos

games.sample(10)
# Out:
#                                                     Name Platform  \
# 13024                         Otogi 2: Immortal Warriors       XB
# 2250                                              NHL 98       PS
# 2467                              ESPN College Hoops 2K5      PS2
# 913                                             Monopoly      Wii
# 11887                   Romance of the Three Kingdoms XI      PS2
# 8814                                           Bomberman       DS
# 1796               Red Dead Redemption: Undead Nightmare      PS3
# 3639                                   Derby Stallion 04      PS2
# 13355                                               Moon       DS
# 10874  Johnny Bravo in The Hukka-Mega-Mighty-Ultra-Ex...       DS
#
#        Year_of_Release      Genre  NA_sales  EU_sales  JP_sales  Other_sales  \
# 13024           2003.0     Action      0.04      0.01      0.00         0.00
# 2250            1997.0     Sports      0.51      0.35      0.00         0.06
# ...

# %%
# Resumen sobre el dataset

games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
# Resumen descriptivo del dataset

games.describe(include = 'all')
# Out:
#                                Name Platform  Year_of_Release   Genre  \
# count                         16713    16715     16446.000000   16713
# unique                        11559       31              NaN      12
# top     Need for Speed: Most Wanted      PS2              NaN  Action
# freq                             12     2161              NaN    3369
# mean                            NaN      NaN      2006.484616     NaN
# std                             NaN      NaN         5.877050     NaN
# min                             NaN      NaN      1980.000000     NaN
# 25%                             NaN      NaN      2003.000000     NaN
# 50%                             NaN      NaN      2007.000000     NaN
# 75%                             NaN      NaN      2010.000000     NaN
# max                             NaN      NaN      2016.000000     NaN
#
#             NA_sales      EU_sales      JP_sales   Other_sales  Critic_Score  \
# ...

# %% [markdown]
# **Descripción**
#
# El DF tiene información de los videojuegos publicados desde el año 1980 hasta la fecha (2016), tiene 11 variables (columnas) y 16715 registros (filas), sus nombres de columnas con estilo de escritura erroneo, ya que es una mezcla entre snake_case y camelCase, además 6 columnas cuentan valores ausentes, 6 columnas usan tipo de dato float y las otras 5 usan object, por ultimo las columnas 'Year_of_Release' y 'User_Score' vienen con un tipo de dato erróneo

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Perfecto! Muy buen trabajo con el entendimiento de tus datos
# </div>

# %% [markdown]
# ## **Preparación de los datos**

# %% [markdown]
# ### Organizando columnas

# %%
# Modificando formato en nombre de columnas a snake_case

new_cols = []
for name in games.columns:
  new_cols.append(name.lower())
  
games.columns = new_cols

# %% [markdown]
# **Organización de columnas**
#
# Se realiza modificación al estilo de escritura en lo nombres de las columnas, convirtiendo el formato, a snake_case.

# %% [markdown]
# ### Cambio en tipo de dato

# %%
# Verificando en columna 'user_score' las calificaciones 'tbd'

games[games['user_score']=='tbd']
# Out:
#                                            name platform  year_of_release  \
# 119                               Zumba Fitness      Wii           2010.0
# 301              Namco Museum: 50th Anniversary      PS2           2005.0
# 520                             Zumba Fitness 2      Wii           2011.0
# 645                                uDraw Studio      Wii           2010.0
# 657    Frogger's Adventures: Temple of the Frog      GBA              NaN
# ...                                         ...      ...              ...
# 16695                           Planet Monsters      GBA           2001.0
# 16697                          Bust-A-Move 3000       GC           2003.0
# 16698                          Mega Brain Boost       DS           2008.0
# 16704                                  Plushees       DS           2008.0
# 16706             Men in Black II: Alien Escape       GC           2003.0
#
#             genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# ...

# %%
# Explorando los años que tiene este tipo de calificación

games[games['user_score'] == 'tbd']['year_of_release'].unique()
# Out:
# array([2010., 2005., 2011.,   nan, 2009., 2004., 1999., 2001., 2008.,
#        2007., 2003., 2000., 2006., 2002., 2015., 2014., 2012., 2013.,
#        2016., 1997.])

# %%
# Cambiando tipo de dato de columna user_score a tipo float

games['user_score'] = pd.to_numeric(games['user_score'], errors='coerce')
games['user_score']
# Out:
# 0        8.0
# 1        NaN
# 2        8.3
# 3        8.0
# 4        NaN
#         ...
# 16710    NaN
# 16711    NaN
# 16712    NaN
# 16713    NaN
# 16714    NaN
# Name: user_score, Length: 16715, dtype: float64

# %%
# Convirtiendo columna 'year_of_release' de float a integer

games['year_of_release'] = games['year_of_release'].astype('Int64')

# %% [markdown]
# **Cambio Tipos de Dato**
#
# Luego, se analizaron las columnas con tipo de dato erróneo, en primer lugar la columna 'user_score' tenia tenia un tipo de dato object, por registros con el dato 'tbd' (a determinar), por lo cual se decidió revisar los años de publicación de los videojuegos con esta nota, y existen varios títulos que lo tienen, siendo el más antiguo desde 1997, por ello, se determinó que esta calificación fuera cambiada a valor nulo; por ultimo, la columna 'year_of_release' se realizó cambio de su tipo de dato de float a integer

# %% [markdown]
# ### Valores Duplicados

# %%
# Existencia de valores duplicados

games.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Valores duplicados**
#
# No existen registros duplicados en dataset

# %% [markdown]
# ### Valores Ausentes

# %%
# Existencia de valores ausentes

games.isnull().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         9125
# rating             6766
# dtype: int64

# %% [markdown]
# **Valores ausentes**
#
# Las columnas con valores ausentes son 6, por lo que a continuación se revisaran los datos de cada una y se determinará el tipo de tratamiento a desarrollar.

# %% [markdown]
# ### Tratamiento Valores Ausentes

# %%
# Registros de los videojuegos sin antecedentes del nombre

games[games['name'].isnull()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN             1993   NaN      1.78      0.53      0.00
# 14244  NaN      GEN             1993   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score  user_score rating
# 659           0.08           NaN         NaN    NaN
# 14244         0.00           NaN         NaN    NaN

# %%
# Registros sin antecedentes del año de lanzamiento

games[games['year_of_release'].isnull()]
# Out:
#                                     name platform  year_of_release  \
# 183                      Madden NFL 2004      PS2             <NA>
# 377                     FIFA Soccer 2004      PS2             <NA>
# 456           LEGO Batman: The Videogame      Wii             <NA>
# 475           wwe Smackdown vs. Raw 2006      PS2             <NA>
# 609                       Space Invaders     2600             <NA>
# ...                                  ...      ...              ...
# 16373  PDC World Championship Darts 2008      PSP             <NA>
# 16405                      Freaky Flyers       GC             <NA>
# 16448                          Inversion       PC             <NA>
# 16458        Hakuouki: Shinsengumi Kitan      PS3             <NA>
# 16522                       Virtua Quest       GC             <NA>
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 183          Sports      4.26      0.26      0.01         0.71          94.0
# ...

# %%
# Eliminando registros del dataset, por falta de información

games.dropna(subset=['name','year_of_release'], axis=0, inplace=True)

# %%
# Obtenemos los generos de video juegos en el dataset

games['genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
# Función para obtener el promedio de calificaciones de critic_score y user_score

def calculate_average(df):
    
    # Agrupar por género y calcular el promedio de cada puntaje
    calc_avg = df.groupby('genre').agg({'critic_score': 'mean','user_score':'mean'}).reset_index()
    return calc_avg

# %%
# calculando promedio de calificación para cada género, y mostrando un dataframe con los valores

avg = calculate_average(games)
avg
# Out:
#            genre  critic_score  user_score
# 0         Action     66.676931    7.058129
# 1      Adventure     65.268750    7.139597
# 2       Fighting     69.155556    7.295949
# 3           Misc     66.648330    6.805828
# 4       Platform     68.124490    7.305896
# 5         Puzzle     67.231818    7.138400
# 6         Racing     68.006897    7.040859
# 7   Role-Playing     72.655267    7.624423
# 8        Shooter     70.260022    7.053260
# 9     Simulation     68.609195    7.132153
# 10        Sports     71.993133    6.951434
# 11      Strategy     72.158784    7.294426

# %%
# Función para reemplazar valores ausentes por la media de los géneros delos videojuegos 

def replace_values(df, promedios):
    
    # Diccionarios con los promedios de cada género
    avg_critic = promedios.set_index('genre')['critic_score'].to_dict()
    avg_user = promedios.set_index('genre')['user_score'].to_dict()
    
    # Reemplazar los valores ausentes en 'critic_score' y 'user_score'
    df['critic_score'] = df['critic_score'].fillna(df['genre'].map(avg_critic))
    df['user_score'] = df['user_score'].fillna(df['genre'].map(avg_user))
    return df

# %%
# Reemplazando los valores de las medias en el dataframe

games = replace_values(games,avg)
games
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16711               LMA Manager 2007     X360             2006        Sports
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16713               Spirits & Spells      GBA             2003      Platform
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %%
# Revisando el nuevo resumen del dataset

games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16444 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16444 non-null  object
#  2   year_of_release  16444 non-null  Int64
#  3   genre            16444 non-null  object
#  4   na_sales         16444 non-null  float64
#  5   eu_sales         16444 non-null  float64
#  6   jp_sales         16444 non-null  float64
#  7   other_sales      16444 non-null  float64
#  8   critic_score     16444 non-null  float64
#  9   user_score       16444 non-null  float64
#  10  rating           9768 non-null   object
# dtypes: Int64(1), float64(6), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# **Tratamiento valores ausentes**
#
# En primer lugar se revisaron los valores ausentes en la columna 'name', que a su vez esos registros tenian mas valores nulos, adicionando los de la columna 'genre', además se observaron los nulos de la columna 'year_of_release', y por ser una información faltante muy relevante se definió eliminar todos estos registros del dataset.
#
# Luego, en la columna 'user_score', por ser una gran cantidad de datos sin información, se calcularon las calificaciones promedio (media) para cada género, y se reemplazaron estos valores nulos por la calificación promedio al genero que corresponde el título.
#
# Por último, los valores nulos de la columna 'rating' no se manipularan por el momento, ya que no es posible obtener o predecir la clasificación ESRB para los títulos que no la poseen.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Buen trabajo! Para este proyecto el eliminar todas las filas que tienen datos ausentes no afectó tu análisis pero habrán casos donde no puedas eliminarlos por que son tus columnas de interés.
#
# Para esos casos dependerá en que tanto tienes de conocimiento de la fuente de datos puesto que muchas veces sabrás la razón del NaN y podrás llenar estos con algún valor en específico, en otros puedes recurrir a llenarlos con la media, mediana, o moda, y en otros cómo aquí sería eliminarlos directamente.
#
# Cómo te menciono esto dependerá en que tanto sabes de la fuente de esos datos para poder procesarlos, pero eliminarlos nos puede hacer perder mucha información.
# </div>

# %% [markdown]
# ### Ingeniería de Características (Feature Engineering)

# %%
# Agregando columna 'total_sales' con las ventas totales de cada juego

games['total_sales'] = games['na_sales'] + games['eu_sales'] + games['jp_sales'] + games['other_sales']

# %%
# Función que genera categorias de la columna 'critic_score'

def critic_category(grade):
    if grade < 20:
        return 'very bad'
    elif grade < 40:
        return 'bad'
    elif grade < 60:
        return 'regular'
    elif grade < 80:
        return 'good'
    else:
        return 'very good'

# %%
# Agregando columna 'critic_category', usando fx critic_category con metodo apply

games['critic_category'] = games['critic_score'].apply(critic_category)

# %%
# Función que genera categorias de la columna 'user_score'

def user_category(grade):
    if grade < 2:
        return 'very bad'
    elif grade < 4:
        return 'bad'
    elif grade < 6:
        return 'regular'
    elif grade < 8:
        return 'good'
    else:
        return 'very good'

# %%
# Agregando columna 'user_category', usando fx user_category con metodo apply

games['user_category'] = games['user_score'].apply(user_category)

# %%
# Revisando el dataset, luego de preparar los datos

games
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16711               LMA Manager 2007     X360             2006        Sports
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16713               Spirits & Spells      GBA             2003      Platform
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %%
# Revisando nuevamente información preliminar del dataset

games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16444 entries, 0 to 16714
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16444 non-null  object
#  2   year_of_release  16444 non-null  Int64
#  3   genre            16444 non-null  object
#  4   na_sales         16444 non-null  float64
#  5   eu_sales         16444 non-null  float64
#  6   jp_sales         16444 non-null  float64
#  7   other_sales      16444 non-null  float64
#  8   critic_score     16444 non-null  float64
#  9   user_score       16444 non-null  float64
#  10  rating           9768 non-null   object
#  11  total_sales      16444 non-null  float64
#  12  critic_category  16444 non-null  object
#  13  user_category    16444 non-null  object
# dtypes: Int64(1), float64(7), object(6)
# memory usage: 1.9+ MB

# %% [markdown]
# **Ingeniería de Características**
#
# Se adicionó una columna consolidada de ventas totales ('total_sales), la cual recoge los datos de 4 columnas ('na_sales, 'eu_sales','jp_sales' y 'other_sales') para representar el mercado global.
#
# Para tratar de comprender mejor las calificaciones de la crítica especilizada ('critic_score') y/o los usuarios ('user_score') se incorporaron 2 columnas ('critic_category' y 'user_category') categorizando ambas variables respectivamente, para asi tener una mejor interpretacion de los datos.

# %% [markdown]
# ### Síntesis del capítulo
#
# En este capítulo, se análizaron varios aspectos del dataset, lo cual llevo a corregir datos erróneos, validar registros duplicados y verificar existencia de valores ausentes y desarrollar su tratamiento. Para luego enriquecer los datos con técnicas de 'Ingeniería de Características'(Feature Engineering).
#
# Finalmente, se concluye que el dataset esta listo, para comenzar con la etapa de análisis del proyecto.

# %% [markdown]
# ## **Análisis exploratorio de datos**

# %% [markdown]
# ### Análisis general de ventas

# %%
# Cantidad de videojuegos lanzados por año

games['year_of_release'].value_counts()
# Out:
# 2008    1427
# 2009    1426
# 2010    1255
# 2007    1197
# 2011    1136
# 2006    1006
# 2005     939
# 2002     829
# 2003     775
# 2004     762
# 2012     653
# 2015     606
# 2014     581
# 2013     544
# 2016     502
# 2001     482
# 1998     379
# 2000     350
# 1999     338
# 1997     289
# 1996     263
# 1995     219
# 1994     121
# 1993      60
# 1981      46
# 1992      43
# 1991      41
# 1982      36
# 1986      21
# 1983      17
# 1989      17
# 1990      16
# 1987      16
# 1988      15
# 1985      14
# 1984      14
# 1980       9
# Name: year_of_release, dtype: Int64

# %% [markdown]
# **Lanzamiento de videojuegos**
#
# La cantidad de videojuegos publicados a lo largo de los años, desde su comienzo en 1980, solo prosperó hasta llegar a un máximo de 1427 videojuegos lanzados en 2008, luego comienza a decrecer, para en 2013 volver aumentar las contidades publicadas hasta la fecha (2016).

# %%
# Plataformas con mayores ventas totales, y más populares

games.groupby('platform').agg({'total_sales':'sum'}).sort_values(by='total_sales',ascending=False).head(10)
# Out:
#           total_sales
# platform
# PS2           1233.56
# X360           961.24
# PS3            931.34
# Wii            891.18
# DS             802.78
# PS             727.58
# PS4            314.14
# GBA            312.88
# PSP            289.53
# 3DS            257.81

# %%
# Plataformas con menores ventas totales, y menos populares

games.groupby('platform').agg({'total_sales':'sum'}).sort_values(by='total_sales').head(10)
# Out:
#           total_sales
# platform
# PCFX             0.03
# GG               0.04
# 3DO              0.10
# TG16             0.16
# WS               1.42
# NG               1.44
# SCD              1.86
# DC              15.95
# GEN             28.35
# SAT             33.59

# %%
# Tabla dinámica con las ventas por año de cada plataforma

games_pt = games.pivot_table(values = 'total_sales',index = 'year_of_release', columns = 'platform', aggfunc = 'sum')
games_pt
# Out:
# platform          2600   3DO    3DS    DC      DS     GB    GBA     GC    GEN  \
# year_of_release
# 1980             11.38   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1981             35.68   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1982             28.88   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1983              5.84   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1984              0.27   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1985              0.45   NaN    NaN   NaN    0.02    NaN    NaN    NaN    NaN
# 1986              0.67   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1987              1.94   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1988              0.74   NaN    NaN   NaN     NaN   1.43    NaN    NaN    NaN
# 1989              0.63   NaN    NaN   NaN     NaN  64.97    NaN    NaN    NaN
# 1990               NaN   NaN    NaN   NaN     NaN   4.89    NaN    NaN   2.60
# ...

# %%
# Grafica de ventas por año de las plataformas de videojuegos

games_pt.plot(kind = 'line',
              figsize = (30, 10),
              marker = 'o',
              grid = True,
              title = 'Ventas totales de videojuegos por plataforma y año',
              xlabel = 'Año de lanzamiento',
              ylabel = 'Ventas totales'
              )
plt.legend(title = 'Plataforma',
           loc = 'upper left'
           )
plt.show()

# %% [markdown]
# **Análisis general de ventas**
#
# Inicialmente se obtuvieron la cantidad de títulos publicados a los largo de la historia, donde el 2008 se obtuvo la cifra record de 1427 ediciones, a que se suma que PlayStation 2 es la plataforma que ha generado mas ventas en toda la historia del gaming.
#
# Posteriormente se graficaron las ventas de cada plataforma a lo largo de la vida, llo que permite inferir y determinar que las plataformas tienen un ciclo de vida de 10 años aproximadamente.

# %% [markdown]
# ### Dataset Modelo Campaña 2017

# %%
# Determinando el dataset relevante para usar en el modelo

games_filter_2006 = games[games['year_of_release'] >= 2006]

# %%
# Revisando dataset filtrado para modelo

games_filter_2006
# Out:
#                                                    name platform  \
# 0                                            Wii Sports      Wii
# 2                                        Mario Kart Wii      Wii
# 3                                     Wii Sports Resort      Wii
# 6                                 New Super Mario Bros.       DS
# 7                                              Wii Play      Wii
# ...                                                 ...      ...
# 16709  SCORE International Baja 1000: The Official Game      PS2
# 16710                     Samurai Warriors: Sanada Maru      PS3
# 16711                                  LMA Manager 2007     X360
# 16712                           Haitaka no Psychedelica      PSV
# 16714                               Winning Post 8 2016      PSV
#
#        year_of_release       genre  na_sales  eu_sales  jp_sales  other_sales  \
# 0                 2006      Sports     41.36     28.96      3.77         8.45
# ...

# %% [markdown]
# **Determinación del dataset**
#
# El periodo elegido para el dataset del modelo (2006-2016), se sustenta, en que los cálculos de datos anteriores, nos indican que las plataformas tiene un ciclo de vida alrededor de 10 años, por lo que es necesario saber cuales fueron las plataformas más populares esta última decada, para predecir el éxito de un videojuego para la campaña 2017.

# %% [markdown]
# ### Análisis de ventas periodo 2006 - 2016

# %%
# Plataformas líderes en ventas desde el 2006 a la fecha

games_filter_2006.groupby('platform').agg({'total_sales':'sum'}).sort_values(by='total_sales',ascending=False).head(5)
# Out:
#           total_sales
# platform
# X360           952.99
# PS3            931.34
# Wii            891.18
# DS             655.35
# PS4            314.14

# %%
# Plataformas con menos ventas desde el 2006 a la fecha

games_filter_2006.groupby('platform').agg({'total_sales':'sum'}).sort_values(by='total_sales').head(5)
# Out:
#           total_sales
# platform
# DC               0.06
# GBA              8.68
# XB              10.77
# GC              11.53
# PSV             53.81

# %%
# Diagrama de caja con las ventas totales de las plataformas

plt.figure(figsize = (10,15))
sns.boxplot(data = games_filter_2006,
            x = 'platform',
            y = 'total_sales')
plt.title('Boxplot de ventas totales por plataforma')
plt.xlabel('Plataforma')
plt.ylabel('Ventas totales (Millones de USD)')
plt.show()

# %%
# Zoom de Diagrama de caja con las ventas totales de las plataformas

plt.figure(figsize = (10,15))
sns.boxplot(data = games_filter_2006,
            x = 'platform',
            y = 'total_sales')
plt.title('Zoom de Boxplot de ventas totales por plataforma')
plt.xlabel('Plataforma')
plt.ylabel('Ventas totales (Millones de USD)')
plt.ylim(0,1.8)
plt.show()

# %%
#

games_filter_2006.sort_values(by='total_sales',ascending=False).head(10)
# Out:
#                          name platform  year_of_release     genre  na_sales  \
# 0                  Wii Sports      Wii             2006    Sports     41.36
# 2              Mario Kart Wii      Wii             2008    Racing     15.68
# 3           Wii Sports Resort      Wii             2009    Sports     15.61
# 6       New Super Mario Bros.       DS             2006  Platform     11.28
# 7                    Wii Play      Wii             2006      Misc     13.96
# 8   New Super Mario Bros. Wii      Wii             2009  Platform     14.44
# 13                    Wii Fit      Wii             2007    Sports      8.92
# 14         Kinect Adventures!     X360             2010      Misc     15.00
# 15               Wii Fit Plus      Wii             2009    Sports      9.01
# 16         Grand Theft Auto V      PS3             2013    Action      7.02
#
#     eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# ...

# %% [markdown]
# **Análisis Boxplot de ventas de videojuegos**
#
# Examinando la primera imagen del diagrama de cajas, se aprecia que todas las plataformas tiene n una gran cantidad de outliers (valores atipicos), es decir, son títulos que sus ventas totales se distancian mucho del promedio del resto de videojuegos, por ejemplo, la plataforma 'Wii', su titulo con mas ventas llega cerca de 80 millones de usd, siendo que el promedio de venta de sus juegos estan alrededor de los 200 mil USD (detalle en la segunda imagen).
#
# Por último, la mediana de las ventas de los videojuegos en todas las plataformas no superan los 300 mil USD, y el tercer cuartil no supera los 800 mil USD, en contraste con titulos que tiene ventas sobre los 80, 30 y 20 millones de USD en algunas plataformas.

# %%
# Cálculo correlación entre las ventas totales y el efecto de las calificaciones de los críticos 


corr_user_sales = games_filter_2006['critic_score'].corr(games_filter_2006['total_sales'])
print(f'La correlación entre las calificaciones de los críticos y las ventas de los videojuegos de PS3 es de: {corr_user_sales:.6f}')

print()


# Gráfico de Dispersión entre ambas variables

games_filter_2006[games_filter_2006['platform'] == 'PS3'].plot(x = 'critic_score', 
                                                               y = 'total_sales',
                                                               kind = 'scatter',
                                                               title = 'Grafico de Dispersión sobre el efecto de las calificaciones de los críticos\nen las ventas de los videojuegos de PlayStation 3',
                                                               xlabel = 'Calificación de la Crítica',
                                                               ylabel = 'Ventas Totales (Millones de USD)',
                                                               xlim = (0,100),
                                                               figsize = (10,10))
plt.show()
# Out:
# La correlación entre las calificaciones de los críticos y las ventas de los videojuegos de PS3 es de: 0.223384

# %%
# Cálculo correlación entre las ventas totales y el efecto de las calificaciones de los usuarios 

corr_user_sales = games_filter_2006['user_score'].corr(games_filter_2006['total_sales'])
print(f'La correlación entre las calificaciones de los usuarios y las ventas de los videojuegos de PS3 es de: {corr_user_sales:.6f}')

print()

# Gráfico de Dispersión entre ambas variables

games_filter_2006[games_filter_2006['platform'] == 'PS3'].plot(x = 'user_score', 
                                                               y = 'total_sales',
                                                               kind = 'scatter',
                                                               title = 'Grafico de Dispersión sobre el efecto de las calificaciones de los usuarios en las ventas de los videojuegos de PlayStation 3',
                                                               xlabel = 'Calificación del Usuario',
                                                               ylabel = 'Ventas Totales (Millones de USD)',
                                                               xlim = (0,10),
                                                               figsize = (10,10))
plt.show()
# Out:
# La correlación entre las calificaciones de los usuarios y las ventas de los videojuegos de PS3 es de: 0.054495

# %% [markdown]
# **Análisis de correlación sobre las calificaciones de críticos y de los usuarios**
#
# Inspeccionando las gráficas, se puede apreciar que la mayoria de las calificaciones, ya sea de criticos o de usuarios, esta por sobre la categoia regular, según columnas 'critic_category' y 'user_category', pero aun asi al medir la correlacion que tienen estas variables con las ventas totales de los videojuegos, el resultado en ambos casos es cercano a 0, por lo indica que su correlación es extremadamente baja entre ambas variables, es decir, la calificaciones de los críticos y los usuarios no afectan las ventas de los videojuegos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Vas por buen camino! Mostraste el gráfico de dispersión entre puntuación de usuario y ventas de manera correcta

# %%
# Obteniendo los 10 videojuegos más vendidos en PS3

games_top_10 = games_filter_2006[games_filter_2006['platform']=='PS3'].sort_values(by='total_sales',ascending=False)['name'].head(10).to_list()
games_top_10 = games_filter_2006[games_filter_2006['name'].isin(games_top_10)]
games_top_10
# Out:
#                                 name platform  year_of_release    genre  \
# 16                Grand Theft Auto V      PS3             2013   Action
# 23                Grand Theft Auto V     X360             2013   Action
# 29    Call of Duty: Modern Warfare 3     X360             2011  Shooter
# 32           Call of Duty: Black Ops     X360             2010  Shooter
# 34        Call of Duty: Black Ops II      PS3             2012  Shooter
# 35        Call of Duty: Black Ops II     X360             2012  Shooter
# 36    Call of Duty: Modern Warfare 2     X360             2009  Shooter
# 37    Call of Duty: Modern Warfare 3      PS3             2011  Shooter
# 41           Call of Duty: Black Ops      PS3             2010  Shooter
# 42                Grand Theft Auto V      PS4             2014   Action
# 51               Grand Theft Auto IV     X360             2008   Action
# 54                    Gran Turismo 5      PS3             2010   Racing
# ...

# %%
# Grafica de las ventas de los 10 videojuegos mas vendidos en todas sus plataformas

plt.figure(figsize=(14, 10))
sns.barplot(x = 'name',
            y = 'total_sales',
            hue = 'platform',
            data = games_top_10, 
            palette = "colorblind")
plt.title('Comparación de ventas del TOP 10 de videojuegos por plataforma')
plt.xlabel('Nombre del videojuego')
plt.ylabel('Ventas Totales')
plt.xticks(rotation=90)
plt.legend(title='Plataforma')
plt.show()

# %% [markdown]
# **Comparación de ventas en varias plataformas**
#
# Este gráfico, muestra una comparación del nivel de ventas de videojuegos mas populares de PlayStation 3 ('PS3') con respecto a otras plataformas, por ejemplo, 'Grand Theft Auto V' que es el juego mas vendido en 'PS3' superando los 20 millones de USD, tambien es el que tiene mayor venta en la plataforma de Xbox 360 ('X360') respecto al resto de titulo en el gráfico, ademas de tener ventas en PlayStation 4 ('PS4'), Xbox One ('XOne') y PC.
#
# Por otra parte, 'FIFA Soccer 13' distribuye sus ventas en 8 plataformas diferentes, asi como también esta 'Gran Turismo 5' que es un videojuego exclusivo de la plataforma PlayStation 3 ('PS3'), por lo que solo genera ventas en esta.
#
# Por ultimo, se concluye que esta útlima decada las plataformas mas populares son PlayStation 3 ('PS3'), Xbox 360 ('X360') y PC.

# %%
# Gráfica de la distribución de los distintas categorias en los videojuegos

plt.figure(figsize = (14, 10))
sns.countplot(x = 'genre', 
              data = games_filter_2006)
plt.title('Distribución de videojuegos por género')
plt.xlabel('Género del videojuego')
plt.ylabel('Número de videojuegos')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Distribución de géneros en las ventas de videojuegos**
#
# La distribución de los generos en videojuegos, esta en su mayoria representada por los titulos de 'Acción', seguido más abajo por títulos de 'Deportes', 'Misceláneos' y de 'Aventura'.
#
# Por ultimo, los géneros menos llamativos son 'Plataforma', continuado por 'Puzzle', 'Estrategia' y 'Lucha'

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Buen trabajo mostrando tus resultados por género
# </div>

# %% [markdown]
# ### Síntesis del capítulo
#
# En este capítulo, los protagonistas fueron los datos de videojuegos y sus ventas, en principio se obtuvieron las distribuciones de videojuegos a lo largo de los años, las plataformas más populares y las más ignoradas por los usuarios, para luego elaborar un gráfico de la distribución de las plataformas a lo largo de los años, que encamino el análisis del ciclo de vida de las plataformas y la determinación del periodo a usar, en el dataset del modelo para la campaña 2017.
#
# Posteriormente, se realizó un análisis de ventas a la última década, buscando en el período las plataformas lideres en ventas y las que están decreciendo, para continuar con un análisis de diagramas de cajas sobre las ventas de las plataformas, con resultados contrastados entre los cuartiles con ventas bajas y sus altos valores extremos de venta.
#
# Luego, se elaboró un estudio de la correlación entre las calificaciones de la crítica y de los usuarios, y las ventas de los videojuegos, el cual demostro que su relacionamiento es casi nulo.
#
# Finalmente, se observaron 2 gráficas, las cuales permitieron decidir las plataformas y los géneros más célebres de la última década.

# %% [markdown]
# ## **Perfil de usuario por región**

# %% [markdown]
# ### Cuota de Mercado

# %%
# Cuota de mercado para las plataformas en Estado Unidos

games_filter_2006.groupby(by='platform')['na_sales'].sum().sort_values(ascending=False).head(5)
# Out:
# platform
# X360    588.84
# Wii     486.87
# PS3     390.13
# DS      323.99
# PS2     114.89
# Name: na_sales, dtype: float64

# %%
# Cuota de mercado para las plataformas en Europa

games_filter_2006.groupby(by='platform')['eu_sales'].sum().sort_values(ascending=False).head(5)
# Out:
# platform
# PS3     327.21
# X360    267.89
# Wii     258.32
# DS      142.99
# PS4     141.09
# Name: eu_sales, dtype: float64

# %%
# Cuota de mercado para las plataformas en Japón

games_filter_2006.groupby(by='platform')['jp_sales'].sum().sort_values(ascending=False).head(5)
# Out:
# platform
# DS     141.49
# 3DS    100.62
# PS3     79.41
# PSP     70.63
# Wii     68.28
# Name: jp_sales, dtype: float64

# %% [markdown]
# **Análisis de cuota de mercado**
#
# Las cuotas de mercado de las plataformas depende mucho de su origen, ya que afecta en algunos mercados, por ejemplo, las 5 plataformas más populares en Japón, son originarias de ese pais, como lo son las plataformas de Sony y Nintendo .
#
# Por otra parte, en Estados Unidos y Europa, 4 de las 5 plataformas más utilizadas se repiten entre las con mayores ventas, pero en Estados Unidos la plataforma es de Microsoft, originaria de ese país, aun asi el dominio de las plataformas niponas se mantiene en la mayoria del mercado.

# %% [markdown]
# ### Géneros Principales

# %%
# Géneros principales en Estados Unidos

games_filter_2006.groupby(by=['genre'])['na_sales'].sum().sort_values(ascending=False).head(5)
# Out:
# genre
# Action          530.44
# Sports          396.64
# Shooter         373.13
# Misc            285.06
# Role-Playing    199.63
# Name: na_sales, dtype: float64

# %%
# Géneros principales en Europa

games_filter_2006.groupby(by=['genre'])['eu_sales'].sum().sort_values(ascending=False).head(5)
# Out:
# genre
# Action     350.70
# Sports     251.55
# Shooter    238.89
# Misc       146.88
# Racing     113.39
# Name: eu_sales, dtype: float64

# %%
# Géneros principales en Japón

games_filter_2006.groupby(by=['genre'])['jp_sales'].sum().sort_values(ascending=False).head(5)
# Out:
# genre
# Role-Playing    170.38
# Action          102.07
# Misc             64.53
# Sports           48.97
# Platform         35.20
# Name: jp_sales, dtype: float64

# %% [markdown]
# **Análisis de géneros en videojuegos según su mercado**
#
# Los géneros de los videojuegos según su mercado, se aprecia que no existe mucha variación, ya que en los mercados evaluados, 3 de los 5 géneros con mas ventas se repiten en todos los mercados, eso implica que para casi todo el mercado de los videojuegos los generos mas exitosos son 'Acción', 'Deportes' y 'Misceláneos'.

# %% [markdown]
# ### Clasificaciones ESRB

# %%
# Ventas totales en Estados Unidos según la clasificación ESRB

games_filter_2006.groupby(by='rating')['na_sales'].sum().sort_values(ascending=False)
# Out:
# rating
# E       796.98
# M       574.33
# T       424.14
# E10+    315.40
# EC        1.32
# RP        0.00
# Name: na_sales, dtype: float64

# %%
# Ventas totales en Europa según la clasificación ESRB

games_filter_2006.groupby(by='rating')['eu_sales'].sum().sort_values(ascending=False)
# Out:
# rating
# E       461.09
# M       398.90
# T       235.44
# E10+    173.35
# RP        0.03
# EC        0.00
# Name: eu_sales, dtype: float64

# %%
# Ventas totales en Japón según la clasificación ESRB

games_filter_2006.groupby(by='rating')['jp_sales'].sum().sort_values(ascending=False)
# Out:
# rating
# E       120.36
# T        83.90
# M        43.79
# E10+     36.57
# EC        0.00
# RP        0.00
# Name: jp_sales, dtype: float64

# %% [markdown]
# **Análisis Clasificaciones ESRB según el mercado**
#
# Por último, el estudio sobre las clasificaciones ESRB, las que nos indican que los juegos con clasificacion "Todos"(E) son los más exitosos, independiente del mercado, seguido por el perfil de jugadores "Adolescentes"(T) mayores de 13 años, "Maduros"(M) jovenes mayores a 17 años, finalizando con "Todos +10"(E10+) personas mayores de 10 años.

# %% [markdown]
# ### Síntesis del capítulo
#
# Se  presenta el dominio de las plataformas niponas ampliamente en el mercado, exceptuado por una plataforma en el mercado anglosajon, pero las demás siguen siendo de Japón.
#
# En otro estudio de géneros, la gloria esta dada en la mayoria del mercado por categorias como 'Acción', 'Deportes y 'Misceláneos'.
#
# Para terminar la investigación del perfil de usuario, la Clasificación ESRB mas influyente es "Todos"(E), es decir, que todas las personas alrededor del mundo lo pueden jugar.

# %% [markdown]
# ## **Pruebas de hipótesis**

# %% [markdown]
# ### Hipótesis 1: Las calificaciones promedio de los usuarios para las plataformas Xbox One y PC son las mismas.

# %%
# Prueba de hipótesis

print('Formulación de Prueba de Hipotesis')
print()
print('H0: Las calificaciones promedio de los usuarios de las plataformas Xbox One y PC son iguales.')
print('H1: Las calificaciones promedio de los usuarios de las plataformas Xbox One y PC son diferentes.')

xone = games_filter_2006[games_filter_2006['platform']=='XOne']['user_score']
pc = games_filter_2006[games_filter_2006['platform']=='PC']['user_score']
print()

alpha = 0.01
print('Nivel de significancia = 1%')
print()

resultado = st.ttest_ind(xone, pc)
print(f'El valor de p_value es: {resultado.pvalue}')
print()
print()
print('Conclusión')
print()

if resultado.pvalue < alpha:
    print('Como el pvalue es menor al nivel de significancia de la prueba, se rechaza la hipótesis nula, ya que hay evidencia\nestadística, con un nivel de confianza del 99%, que las calificaciones promedio de los usuarios de las plataformas\nXbox One y PC son diferentes.')
else:
    print('Como el pvalue es mayor al nivel de significancia de la prueba, se aprueba la hipótesis nula, ya que hay evidencia\nestadística, con un nivel de confianza del 99%, que las calificaciones promedio de los usuarios de las plataformas\nXbox One y PC son iguales.')
# Out:
# Formulación de Prueba de Hipotesis
#
# H0: Las calificaciones promedio de los usuarios de las plataformas Xbox One y PC son iguales.
# H1: Las calificaciones promedio de los usuarios de las plataformas Xbox One y PC son diferentes.
#
# Nivel de significancia = 1%
#
# El valor de p_value es: 0.020460224291219138
#
#
# Conclusión
#
# Como el pvalue es mayor al nivel de significancia de la prueba, se aprueba la hipótesis nula, ya que hay evidencia
# estadística, con un nivel de confianza del 99%, que las calificaciones promedio de los usuarios de las plataformas
# Xbox One y PC son iguales.

# %% [markdown]
# ### Hipótesis 2: Las calificaciones promedio de los usuarios para los géneros de Acción y Deportes son diferentes.

# %%
# Prueba de hipótesis

print('Formulación de Prueba de Hipotesis')
print()
print('H0: Las calificaciones promedio de los usuarios sobre los generos de Acción y Deportes en videojuegos son iguales.')
print('H1: Las calificaciones promedio de los usuarios sobre los generos de Acción y Deportes en videojuegos son diferentes.')

action = games_filter_2006[games_filter_2006['genre']=='Action']['user_score']
sport = games_filter_2006[games_filter_2006['genre']=='Sports']['user_score']
print()
alpha = 0.01
print('Nivel de significancia = 1%')
print()

resultado = st.ttest_ind(action, sport)
print(f'El valor de p_value es: {resultado.pvalue}')
print()
print()
print('Conclusión')
print()

if resultado.pvalue < alpha:
    print('Como el pvalue es menor al nivel de significancia de la prueba, se rechaza la hipotesis nula, ya que hay evidencia\nestadística, con un nivel de confianza del 99%, que las calificaciones promedio de los usuarios sobre los generos\nde Acción y Deportes en videojuegos son diferentes.')
else:
    print('Como el pvalue es mayor al nivel de significancia de la prueba, se aprueba la hipotesis nula, ya que hay evidencia\nestadística, con un nivel de confianza del 99%, que las calificaciones promedio de los usuarios sobre los generos\nde Acción y Deportes en videojuegos son iguales.')
# Out:
# Formulación de Prueba de Hipotesis
#
# H0: Las calificaciones promedio de los usuarios sobre los generos de Acción y Deportes en videojuegos son iguales.
# H1: Las calificaciones promedio de los usuarios sobre los generos de Acción y Deportes en videojuegos son diferentes.
#
# Nivel de significancia = 1%
#
# El valor de p_value es: 2.4049646555661416e-14
#
#
# Conclusión
#
# Como el pvalue es menor al nivel de significancia de la prueba, se rechaza la hipotesis nula, ya que hay evidencia
# estadística, con un nivel de confianza del 99%, que las calificaciones promedio de los usuarios sobre los generos
# de Acción y Deportes en videojuegos son diferentes.

# %% [markdown]
# ### Síntesis del capítulo
#
# Elaboración de pruebas de hipótesis para fundamentar mediante los datos el modelo de la campaña 2017, para ello, se realizaron 2 preguntas, en las cuales se utilizo un nivel de significancia del 1%, debido a que es un modelo para realizar una campaña de un año, las pruebas debe ser más exhaustiva. Las interrogantes son las siguientes:
#
#
#     - Hipótesis 1: Las calificaciones promedio de los usuarios para las plataformas Xbox One y PC son las mismas.
#
#     Conclusión: Las calificaciones de los usuarios a las plataformas de Xbox One y PC en promedio son iguales.
#
#
#     - Hipótesis 2: Las calificaciones promedio de los usuarios para los géneros de Acción y Deportes son diferentes.
#
#     Conclusión: Las calificaciones de los usuarios a los géneros de Acción y Deportes en promedio son diferentes.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Hiciste una buena aplicación de las pruebas de hipótesis y respondiste las preguntas en base a esto de manera adecuado, buen trabajo!
# </div>

# %% [markdown]
# ## **Conclusión general**

# %% [markdown]
# Los videojuegos tienen un gran futuro en la industria tecnológica, por ello, el estudio realizado tiene sentido poder realzar más esta afirmación, y poder proyectarla hacia el próximo año basandose en la historia de este negocio y sus particularidades.
#
# <br>
#
# ***Información general***
#
# Inicialmente, se accedió a la descripción general del proyecto, los documentos a utilizar, resumen de su contenido, y las cuestiones a resolver en este estudio. Por ello, primeramente se obtubieron las liberias de Python para procesar y analizar los datos de la empresa, para este caso, se uso Pandas, Numpy, Scipy, Matplotlib y Seaborn.
#
# Luego el archivo ('.csv') fue importado y cargado sus datos en el sistema, para obtener informacion preliminar al análisis, el cual nos entrega la siguiente información:
#
#         - Número de Filas y número de columnas.
#         - Tipo de dato de cada columna.
#         - Nombres de cada columna del archivo.
#         - Datos no nulos por columna (valores ausentes).
#         - Resumen de los tipos de datos usados por el DataFrame
#         - Memoria usada por el DataFrame
#
# Para el estudio, se obtuvo información relevante:
#
# - games: Total: 16715 filas y 11 columnas
#          Tipos de dato: Object(string), numeros enteros y flotantes (decimales)
#          Valores ausentes: 6 columnas
#
# <br>
#
# ***Preparación de los datos***
#
# Luego,con la información anterior, se gestionó la corrección de los datos erroneos, verificación de duplicados y valores ausentes y se aplicaron algunos conceptos de 'Feature Engineering', lo cual permite, a partir de los datos ya generados, agregar otras variables que clarifican y simplifican el análisis, por lo cual se realizaron las siguientes etapas:
#
#     Organización de columnas: Cambio de formato a snake_case
#
#     Cambio de tipos de dato: Modificación de datos erróneos object(string) a float y nulos 1 columna (user_score),
#                                                             float a integer 1columna (year_of_release)
#
#     Valores duplicados: No existen valores duplicados en el dataset
#
#     Valores Ausentes: 6 columnas
#
#     Tratamiento Valores Ausentes: Eliminación 3 columnas (name, year_of_release, genre)
#                                   Imputación por la media 2 columnas (critic_score, user_score)
#                                   Conservación 1 columna (rating)
#
#     Ingeniería de Características: Inserción 3 columnas (total_sales, critic_category, user_score)
#
# <br>
#
# ***Análisis exploratorio de datos***
#
# Con el dataset corregido y preparado para el estudio, se define comienzar el análisis de ventas, para el cual los datos nos proporcionan detalles, de lo que ha sido la historia de los videojuegos, desde sus comienzos (1980), a la actualidad (2016), llegando a niveles historicos en el 2008 con 1427 títulos publicados, y teniendo empresas como Sony con sus plataformas PlayStation 2 (la consola con más títulos vendidos en la historia) y Playstation 3, Nintendo con sus plataformas Wii y Nintendo DS y Microsoft con su plataforma Xbox 360.
#
# En este análisis, se comprueba que las plataformas tienen un ciclo de vida comercial de 10 años aproximadamente, por ello, es que se define para el modelo de la campaña 2017 trabajar, con un dataset compuesto desde el año 2006 hasta la fecha, ya que con esto se podrá obtener un panorama mas representativo del mercado de los videojuegos en la última década, y poder proyectar esto en la planificación de la campaña del proximo año.
#
# Posteriormente en formación del estudio, se representaron las plataformas más famosas de la última década en la cual Xbox 360 es la mas exitosa, seguida por Playstation 3 y Wii, luego con un diagrama de cajas se interpretaron las ventas de las plataformas en el periodo, donde se distingue el contraste de la mayoria de estas, que el promedio de ventas de sus titulos son muy bajos, pero existen varios videojuegos que rompen esa regla con ventas muy altas, que los situan como valores atípicos (outliers). A considerar las plataformas de PlayStation 4, PC y Xbox One, las cuales son la siguiente generación de plataformas para esta década
#
# Para profundizar más en el estudio, se evaluaron las calificaciones de los críticos especializados y/o los usuarios respecto a si influyen en las ventas de los videojuegos, y para tener fundamento se representaron ambas variables en relación a las ventas mediante un gráfico de dispersión y se cálculo el coeficiente de correlación para las dos situaciones; lo que finalmente concluyo en que ninguna de las variables tiene un efecto en las ventas de la industria del gaming, ya que la conexión de estos atributos es casi inexistente.
#
# Siguiendo con la investigación, se evaluaron la ventas de videojuegos en diversas plataformas, lo que lleva a concluir que las plataformas más célebres son PlayStation 3, Xbox 360 y PC; a lo que se adiciona un estudio sobre los géneros de los videojuegos que los más éxitosos son de Acción, Deportes y Misceláneo.
#
# <br>
#
# ***Perfil usuario por región***
#
# A continuación, se indagaron los perfiles de los usuarios del negocio, para ello, en principio se evaluo la cuota de mercado de la plataformas, en que las empresas japonesas (Sony y Nintendo) dominan los primeros lugares en el mercado global esceptuando en Estados Unidos que se adelanta la plataforma de Microsoft, este estudio tambien refleja que se mantienen las preferencia de los usuarios por los géneros de Acción, Deportes y Misceláneo, a la hora de escoger un nuevo juego.
#
# Internacionalmente muchos juegos cuenta con una Clasificación ESRB, la cual permite, mediante la edad de las personas, saber si el juego y su contenido es adecuado para este, por ello, la clasificación mas exitosa es "E"(Todos), la cual permite que cualquier persona independiente de la edad pueda entretenerse con ese videojuego.
#
# <br>
#
# ***Prueba de Hipótesis***
#
# Por último, se realizaron 2 pruebas de hipotesis, donde se estudió lo siguiente:
#
# *Hipotesis 1*: Las calificaciones promedio de los usuarios para las plataformas Xbox One y PC son las mismas.
#
#     H0: Las calificaciones promedio de los usuarios para las plataformas Xbox One y PC son iguales.
#
#     H1: Las calificaciones promedio de los usuarios de las plataformas Xbox One y PC son diferentes.
#
# Nivel de significancia = 1%
#
# El valor de p_value es: 0.020460224291219138
#
# Resolución
#
# Como el pvalue es mayor al nivel de significancia de la prueba, se aprueba la hipótesis nula, ya que hay evidencia
# estadística, con un nivel de confianza del 99%, que las calificaciones promedio de los usuarios de las plataformas
# Xbox One y PC son iguales.
#
# <br>
#
# *Hipótesis 2*: Las calificaciones promedio de los usuarios para los géneros de Acción y Deportes son diferentes.
#
#     H0: Las calificaciones promedio de los usuarios en géneros de Acción y Deportes en videojuegos son iguales.
#
#     H1: Las calificaciones promedio de los usuarios en géneros de Acción y Deportes en videojuegos son diferentes.
#
# Nivel de significancia = 1%
#
# El valor de p_value es: 2.4049646555661416e-14
#
# Resolución
#
# Como el pvalue es menor al nivel de significancia de la prueba, se rechaza la hipotesis nula, ya que hay evidencia
# estadística, con un nivel de confianza del 99%, que las calificaciones promedio de los usuarios sobre los generos
# de Acción y Deportes en videojuegos son diferentes.
#
# <br>
#
# ***Resumen***
#
# Un gran proyecto, donde se analizó la historia de un negocio que tiene mucho que decir, empezando por sus plataformas más exitosas en la actualidad como PlayStation 3, Xbox 360 y Wii, pero se termina su ciclo de vida, por ello, no dejar de considerar a PlayStation 4 y Xbox One que es la siguiente generación de plataformas, en otro punto, los géneros más llamativos para los usuarios son de Acción, Deportes y Misceláneo; teniendo en cuenta que la mayoria de títulos tienen clasificación ESRB para todas las edades ya que es la más popular, considerar los puntos tratados para desarrollar la predicción.
#
# Por ultimo, este informe permite proyectar las directrices para elaborar un modelo de videojuego exitoso para la campaña 2017, ya que considera los aspectos mas representativos de es te tipo de producto como la plataforma, el género, su clasificación ESRB y un análisis del mercado en el cual se va a publicar y desenvolver el videojuego.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Comentario general (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
#
# Se nota tu manejo de las diferentes librerías para llevar a cabo tu proyecto y debo destacar lo ordenado que has presentado tu proyecto, te felicito!
# <br>
# <br>
# Generaste visualizaciones muy buenas y a partir de estas sacaste buenas conclusiones que complementaron tu análisis a la perfección.
# <br>
# <br>
# Te he dejado mis comentarios a lo largo del proyecto y espero que te sirvan de ayuda para tus próximos proyectos!
# Un saludo! 🦾
# </div>
